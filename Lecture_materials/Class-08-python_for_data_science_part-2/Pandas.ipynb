# %% [markdown]
# # Pandas
#
# pandas -> Panel Data
#
# Panel Data is like spreadsheet. In relational database also you have this spreadsheet like format where each columns are fields, and each rows are called entries.
#
# [Pandas Documentation](https://pandas.pydata.org/docs/)
#
# install `pandas` in your virtual environement using `pip install pandas`
#
# ---
#
# ## Advantages of pandas
#
# 1. Fast execution
# 2. Enriched I/O: It has APIs to read from various sources (csv, xlsx, rdbms, html, etc.) and it can also write in those formats.
# 3. Open source community

# %%
import pandas as pd
import numpy as np    # importing numpy also for data manipulation

# %% [markdown]
# ### Pandas Series

# %%
s = pd.Series(data=[1, 2, 3.2, 4, 5], index=None)

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.2
# 3    4.0
# 4    5.0
# dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s = pd.Series(data=[1, 2, 3.2, 4, 5], index=['a','b','c','d','e'])

s
# Out:
# a    1.0
# b    2.0
# c    3.2
# d    4.0
# e    5.0
# dtype: float64

# %%
independence = {"India": 1947, "Bangladesh": 1971, "China": 1945}

pd.Series(independence)
# Out:
# India         1947
# Bangladesh    1971
# China         1945
# dtype: int64

# %% [markdown]
# ### Pandas DataFrame
#
# ```python
# df = pd.DataFrame(data, index=None, columns=None)
# ````

# %%
arr = np.array([[3,0],[2,3],[0,7],[1,2]])

arr
# Out:
# array([[3, 0],
#        [2, 3],
#        [0, 7],
#        [1, 2]])

# %%
arr.shape
# Out:
# (4, 2)

# %%
pd.DataFrame(arr)
# Out:
#    0  1
# 0  3  0
# 1  2  3
# 2  0  7
# 3  1  2

# %%
pd.DataFrame(arr, index=['a','b','c','d'], columns=['xyz', 'pqr'])
# Out:
#    xyz  pqr
# a    3    0
# b    2    3
# c    0    7
# d    1    2

# %%
df = pd.DataFrame(arr, columns=['apple', 'orange'])

df
# Out:
#    apple  orange
# 0      3       0
# 1      2       3
# 2      0       7
# 3      1       2

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dict1 = {"apples": [3, 2, 0, 1], "oranges": [0, 3, np.nan, 2]}

pd.DataFrame(dict1)
# Out:
#    apples  oranges
# 0       3      0.0
# 1       2      3.0
# 2       0      NaN
# 3       1      2.0

# %%
pd.DataFrame(dict1, columns=["apples"])
# Out:
#    apples
# 0       3
# 1       2
# 2       0
# 3       1

# %% [markdown]
# ### Different Data Fetching Techniques in Pandas
#
# Pandas provide different funtions to read from various data sources.
# Following are some `read_*()` functions to read data from popular sources.
#
# #### 1. Read CSV
# ```python
#     import pandas as pd
#     df = pd.read_csv("data.csv")
# ```
#
# #### 2. Read Excel
# ```python
#     df = pd.read_excel("data.xlsx", sheet_name="Sheet1")
# ```
#
# #### 3. Read JSON
# ```python
#     df = pd.read_json("data.json")
# ```
#
# #### 4. Read SQL Databases
# ```python
#     import sqlite3
#     conn = sqlite3.connect("mydb.sqlite")
#     df = pd.read_sql("SELECT * FROM customers", conn)
# ```
# Read full table:
# ```python
#     df = pd.read_sql_table("customers", conn)
# ```
#
# #### 5. Read HTML Tables
# ```python
#     tables = pd.read_html("https://example.com")
#     df = tables[0]
# ```
#
# #### 6. Read from URL
#
# Any read_* function also works with URLs:
#
# ```
#     df = pd.read_csv("https://raw.githubusercontent.com/.../data.csv")
# ```

# %%
# Example: reading from csv file 

covid_data = pd.read_csv("./worldometer_coronavirus_summary_data.csv")

covid_data
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           179267
# 1                      Albania             Europe           275574
# 2                      Algeria             Africa           265816
# 3                      Andorra             Europe            42156
# 4                       Angola             Africa            99194
# ..                         ...                ...              ...
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          7690.0         162202.0        9375.0               1124.0
# 1          3497.0         271826.0         251.0                  2.0
# 2          6875.0         178371.0       80570.0                  6.0
# 3           153.0          41021.0         982.0                 14.0
# 4          1900.0          97149.0         145.0                  NaN
# ..            ...              ...           ...                  ...
# 221           7.0            438.0           9.0                  NaN
# 222           1.0              9.0           0.0                  NaN
# 223        2149.0           9009.0         661.0                 23.0
# 224        3983.0         315997.0         611.0                  NaN
# 225        5482.0         242417.0        1307.0                 12.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                             4420                           190.0
# 1                            95954                          1218.0
# 2                             5865                           152.0
# 3                           543983                          1974.0
# 4                             2853                            55.0
# ..                             ...                             ...
# 221                          41755                           644.0
# 222                             16                             2.0
# 223                            381                            69.0
# 224                          16575                           206.0
# 225                          16324                           359.0
#
#      total_tests  total_tests_per_1m_population  population
# 0       951337.0                        23455.0    40560636
# 1      1817530.0                       632857.0     2871945
# 2       230861.0                         5093.0    45325517
# 3       249838.0                      3223924.0       77495
# 4      1499795.0                        43136.0    34769277
# ..           ...                            ...         ...
# 221      20508.0                      1886140.0       10873
# 222          NaN                            NaN      624681
# 223     265253.0                         8543.0    31049015
# 224    3452554.0                       178497.0    19342381
# 225    2287793.0                       149863.0    15265849
#
# [226 rows x 12 columns]

# %%
# Example: reading from URL

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

titanic_data = pd.read_csv(url)

titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Data Writing Techniques in Pandas
#
# Similar to `read_*()` functions which allows to read data from various sources, there are also `to_*()` functions.
#
# #### 1. Write to CSV
# ```python
#     df.to_csv("output.csv", index=False)
# ```
#
# #### 2. Write to Excel
#
# ```python
#     df.to_excel("output.xlsx", sheet_name="Sheet1", index=False)
# ```
#
# #### 3. Write to JSON
#
# ```python
#     df.to_json("output.json")
#
#     df.to_json("output_pretty.json", indent=4)
# ```
#
# #### 4. Write to SQL Table
#
# ```python
#     from sqlalchemy import create_engine
#     engine = create_engine("sqlite:///mydb.sqlite")
#     df.to_sql("customers", engine, if_exists="replace", index=False)
# ```

# %%
# Example: write titanic datafrmae to csv

titanic_data.to_csv("./titanic_data.csv", index=False)

# by default pandas will put index in a preceeding column. If index=False it will not put the index column

# %% [markdown]
# ### head() and tail()

# %%
covid_data.head() # shows top 5 rows by default
# Out:
#        country continent  total_confirmed  total_deaths  total_recovered  \
# 0  Afghanistan      Asia           179267        7690.0         162202.0
# 1      Albania    Europe           275574        3497.0         271826.0
# 2      Algeria    Africa           265816        6875.0         178371.0
# 3      Andorra    Europe            42156         153.0          41021.0
# 4       Angola    Africa            99194        1900.0          97149.0
#
#    active_cases  serious_or_critical  total_cases_per_1m_population  \
# 0        9375.0               1124.0                           4420
# 1         251.0                  2.0                          95954
# 2       80570.0                  6.0                           5865
# 3         982.0                 14.0                         543983
# 4         145.0                  NaN                           2853
#
#    total_deaths_per_1m_population  total_tests  total_tests_per_1m_population  \
# 0                           190.0     951337.0                        23455.0
# 1                          1218.0    1817530.0                       632857.0
# 2                           152.0     230861.0                         5093.0
# 3                          1974.0     249838.0                      3223924.0
# 4                            55.0    1499795.0                        43136.0
#
#    population
# 0    40560636
# 1     2871945
# 2    45325517
# 3       77495
# 4    34769277

# %%
covid_data.head(10)  # .head(n) shows top n rows of the dataframe
# Out:
#                country      continent  total_confirmed  total_deaths  \
# 0          Afghanistan           Asia           179267        7690.0
# 1              Albania         Europe           275574        3497.0
# 2              Algeria         Africa           265816        6875.0
# 3              Andorra         Europe            42156         153.0
# 4               Angola         Africa            99194        1900.0
# 5             Anguilla  North America             2984           9.0
# 6  Antigua And Barbuda  North America             7721         137.0
# 7            Argentina  South America          9101319      128729.0
# 8              Armenia           Asia           422896        8623.0
# 9                Aruba  North America            35693         213.0
#
#    total_recovered  active_cases  serious_or_critical  \
# 0         162202.0        9375.0               1124.0
# 1         271826.0         251.0                  2.0
# 2         178371.0       80570.0                  6.0
# 3          41021.0         982.0                 14.0
# 4          97149.0         145.0                  NaN
# 5           2916.0          59.0                  4.0
# 6           7511.0          73.0                  1.0
# 7        8895999.0       76591.0                372.0
# 8         412048.0        2225.0                  NaN
# 9          35199.0         281.0                  NaN
#
#    total_cases_per_1m_population  total_deaths_per_1m_population  total_tests  \
# 0                           4420                           190.0     951337.0
# 1                          95954                          1218.0    1817530.0
# 2                           5865                           152.0     230861.0
# 3                         543983                          1974.0     249838.0
# 4                           2853                            55.0    1499795.0
# 5                         195646                           590.0      51382.0
# 6                          77646                          1378.0      18901.0
# 7                         197992                          2800.0   35716069.0
# 8                         142219                          2900.0    3068217.0
# 9                         331689                          1979.0     177885.0
#
#    total_tests_per_1m_population  population
# 0                        23455.0    40560636
# 1                       632857.0     2871945
# 2                         5093.0    45325517
# 3                      3223924.0       77495
# 4                        43136.0    34769277
# 5                      3368870.0       15252
# 6                       190076.0       99439
# 7                       776974.0    45968174
# 8                      1031834.0     2973558
# 9                      1653053.0      107610

# %%
covid_data.tail(8)
# Out:
#                        country          continent  total_confirmed  \
# 218                    Vanuatu  Australia/Oceania             8457
# 219                  Venezuela      South America           522921
# 220                   Viet Nam               Asia         10696630
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 218          14.0           7974.0         469.0                  NaN
# 219        5711.0         516170.0        1040.0                230.0
# 220       43065.0        9355040.0     1298525.0                340.0
# 221           7.0            438.0           9.0                  NaN
# 222           1.0              9.0           0.0                  NaN
# 223        2149.0           9009.0         661.0                 23.0
# 224        3983.0         315997.0         611.0                  NaN
# 225        5482.0         242417.0        1307.0                 12.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 218                          26386                            44.0
# 219                          18487                           202.0
# 220                         108080                           435.0
# 221                          41755                           644.0
# 222                             16                             2.0
# 223                            381                            69.0
# 224                          16575                           206.0
# 225                          16324                           359.0
#
#      total_tests  total_tests_per_1m_population  population
# 218      24976.0                        77926.0      320508
# 219    3359014.0                       118752.0    28285909
# 220   85811485.0                       867048.0    98969721
# 221      20508.0                      1886140.0       10873
# 222          NaN                            NaN      624681
# 223     265253.0                         8543.0    31049015
# 224    3452554.0                       178497.0    19342381
# 225    2287793.0                       149863.0    15265849

# %% [markdown]
# ### shape, len, info() and describe()

# %%
covid_data.shape  # (rows , cols)
# Out:
# (226, 12)

# %%
len(covid_data)  # number of rows
# Out:
# 226

# %%
covid_data.info() # info gives column name, number of null in each column and the Dtype along with other details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         226 non-null    object
#  1   continent                       226 non-null    object
#  2   total_confirmed                 226 non-null    int64
#  3   total_deaths                    218 non-null    float64
#  4   total_recovered                 204 non-null    float64
#  5   active_cases                    204 non-null    float64
#  6   serious_or_critical             145 non-null    float64
#  7   total_cases_per_1m_population   226 non-null    int64
#  8   total_deaths_per_1m_population  218 non-null    float64
#  9   total_tests                     212 non-null    float64
#  10  total_tests_per_1m_population   212 non-null    float64
#  11  population                      226 non-null    int64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 21.3+ KB

# %%
covid_data.describe()  # provides a statistical summary of all the numerical (int or float) columns
# Out:
#        total_confirmed  total_deaths  total_recovered  active_cases  \
# count     2.260000e+02  2.180000e+02     2.040000e+02  2.040000e+02
# mean      2.305651e+06  2.884442e+04     2.256851e+06  6.861029e+04
# std       7.575510e+06  9.971254e+04     7.613357e+06  2.350430e+05
# min       2.000000e+00  1.000000e+00     1.000000e+00  0.000000e+00
# 25%       2.412600e+04  2.370000e+02     1.619300e+04  2.397500e+02
# 50%       1.793750e+05  2.251500e+03     1.372740e+05  1.634000e+03
# 75%       1.090902e+06  1.400650e+04     1.006245e+06  1.929675e+04
# max       8.420947e+07  1.026646e+06     8.124426e+07  1.938567e+06
#
#        serious_or_critical  total_cases_per_1m_population  \
# count           145.000000                     226.000000
# mean            269.482759                  148156.809735
# std             883.174727                  155202.909225
# min               1.000000                      16.000000
# 25%               5.000000                   11748.250000
# 50%              17.000000                   98271.500000
# 75%             139.000000                  255632.750000
# max            8318.000000                  704302.000000
#
#        total_deaths_per_1m_population   total_tests  \
# count                      218.000000  2.120000e+02
# mean                      1157.550459  2.987445e+07
# std                       1212.833590  1.079635e+08
# min                          2.000000  5.117000e+03
# 25%                        172.500000  3.472968e+05
# 50%                        768.000000  2.238918e+06
# 75%                       1850.000000  1.233862e+07
# max                       6297.000000  1.016883e+09
#
#        total_tests_per_1m_population    population
# count                   2.120000e+02  2.260000e+02
# mean                    1.944650e+06  3.495521e+07
# std                     3.318400e+06  1.390338e+08
# min                     5.093000e+03  8.050000e+02
# 25%                     1.667260e+05  5.605125e+05
# 50%                     7.753355e+05  5.800570e+06
# 75%                     2.267408e+06  2.187284e+07
# max                     2.184247e+07  1.439324e+09

# %% [markdown]
# ### Slicing and Dicing

# %%
covid_data.columns  # Shows the name of all the columns
# Out:
# Index(['country', 'continent', 'total_confirmed', 'total_deaths',
#        'total_recovered', 'active_cases', 'serious_or_critical',
#        'total_cases_per_1m_population', 'total_deaths_per_1m_population',
#        'total_tests', 'total_tests_per_1m_population', 'population'],
#       dtype='object')

# %%
list(covid_data.columns)
# Out:
# ['country',
#  'continent',
#  'total_confirmed',
#  'total_deaths',
#  'total_recovered',
#  'active_cases',
#  'serious_or_critical',
#  'total_cases_per_1m_population',
#  'total_deaths_per_1m_population',
#  'total_tests',
#  'total_tests_per_1m_population',
#  'population']

# %%
covid_data
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           179267
# 1                      Albania             Europe           275574
# 2                      Algeria             Africa           265816
# 3                      Andorra             Europe            42156
# 4                       Angola             Africa            99194
# ..                         ...                ...              ...
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          7690.0         162202.0        9375.0               1124.0
# 1          3497.0         271826.0         251.0                  2.0
# 2          6875.0         178371.0       80570.0                  6.0
# 3           153.0          41021.0         982.0                 14.0
# 4          1900.0          97149.0         145.0                  NaN
# ..            ...              ...           ...                  ...
# 221           7.0            438.0           9.0                  NaN
# 222           1.0              9.0           0.0                  NaN
# 223        2149.0           9009.0         661.0                 23.0
# 224        3983.0         315997.0         611.0                  NaN
# 225        5482.0         242417.0        1307.0                 12.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                             4420                           190.0
# 1                            95954                          1218.0
# 2                             5865                           152.0
# 3                           543983                          1974.0
# 4                             2853                            55.0
# ..                             ...                             ...
# 221                          41755                           644.0
# 222                             16                             2.0
# 223                            381                            69.0
# 224                          16575                           206.0
# 225                          16324                           359.0
#
#      total_tests  total_tests_per_1m_population  population
# 0       951337.0                        23455.0    40560636
# 1      1817530.0                       632857.0     2871945
# 2       230861.0                         5093.0    45325517
# 3       249838.0                      3223924.0       77495
# 4      1499795.0                        43136.0    34769277
# ..           ...                            ...         ...
# 221      20508.0                      1886140.0       10873
# 222          NaN                            NaN      624681
# 223     265253.0                         8543.0    31049015
# 224    3452554.0                       178497.0    19342381
# 225    2287793.0                       149863.0    15265849
#
# [226 rows x 12 columns]

# %%
covid_data['total_confirmed']  # fetches just the column in Series
# Out:
# 0      179267
# 1      275574
# 2      265816
# 3       42156
# 4       99194
#         ...
# 221       454
# 222        10
# 223     11819
# 224    320591
# 225    249206
# Name: total_confirmed, Length: 226, dtype: int64

# %%
type(covid_data['total_confirmed'])
# Out:
# pandas.core.series.Series

# %%
covid_data.total_confirmed  # this is another (not recommended) way
# Out:
# 0      179267
# 1      275574
# 2      265816
# 3       42156
# 4       99194
#         ...
# 221       454
# 222        10
# 223     11819
# 224    320591
# 225    249206
# Name: total_confirmed, Length: 226, dtype: int64

# %%
data_selected = covid_data[['total_confirmed', 'total_deaths', 'total_recovered']]

# creates a dataframe from the original dataframe with the specified columns

data_selected
# Out:
#      total_confirmed  total_deaths  total_recovered
# 0             179267        7690.0         162202.0
# 1             275574        3497.0         271826.0
# 2             265816        6875.0         178371.0
# 3              42156         153.0          41021.0
# 4              99194        1900.0          97149.0
# ..               ...           ...              ...
# 221              454           7.0            438.0
# 222               10           1.0              9.0
# 223            11819        2149.0           9009.0
# 224           320591        3983.0         315997.0
# 225           249206        5482.0         242417.0
#
# [226 rows x 3 columns]

# %%
covid_data
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           179267
# 1                      Albania             Europe           275574
# 2                      Algeria             Africa           265816
# 3                      Andorra             Europe            42156
# 4                       Angola             Africa            99194
# ..                         ...                ...              ...
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          7690.0         162202.0        9375.0               1124.0
# 1          3497.0         271826.0         251.0                  2.0
# 2          6875.0         178371.0       80570.0                  6.0
# 3           153.0          41021.0         982.0                 14.0
# 4          1900.0          97149.0         145.0                  NaN
# ..            ...              ...           ...                  ...
# 221           7.0            438.0           9.0                  NaN
# 222           1.0              9.0           0.0                  NaN
# 223        2149.0           9009.0         661.0                 23.0
# 224        3983.0         315997.0         611.0                  NaN
# 225        5482.0         242417.0        1307.0                 12.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                             4420                           190.0
# 1                            95954                          1218.0
# 2                             5865                           152.0
# 3                           543983                          1974.0
# 4                             2853                            55.0
# ..                             ...                             ...
# 221                          41755                           644.0
# 222                             16                             2.0
# 223                            381                            69.0
# 224                          16575                           206.0
# 225                          16324                           359.0
#
#      total_tests  total_tests_per_1m_population  population
# 0       951337.0                        23455.0    40560636
# 1      1817530.0                       632857.0     2871945
# 2       230861.0                         5093.0    45325517
# 3       249838.0                      3223924.0       77495
# 4      1499795.0                        43136.0    34769277
# ..           ...                            ...         ...
# 221      20508.0                      1886140.0       10873
# 222          NaN                            NaN      624681
# 223     265253.0                         8543.0    31049015
# 224    3452554.0                       178497.0    19342381
# 225    2287793.0                       149863.0    15265849
#
# [226 rows x 12 columns]

# %% [markdown]
# #### `iloc`

# %%
covid_data.iloc[1]  # takes the row with index=1 in series
# Out:
# country                             Albania
# continent                            Europe
# total_confirmed                      275574
# total_deaths                         3497.0
# total_recovered                    271826.0
# active_cases                          251.0
# serious_or_critical                     2.0
# total_cases_per_1m_population         95954
# total_deaths_per_1m_population       1218.0
# total_tests                       1817530.0
# total_tests_per_1m_population      632857.0
# population                          2871945
# Name: 1, dtype: object

# %%
covid_data.iloc[0,0]   # first element of the first row
# Out:
# 'Afghanistan'

# %%
covid_data.iloc[2,5]
# Out:
# np.float64(80570.0)

# %%
covid_data.iloc[0:5, 3:6]  # rows 0, 1, 2, 3, 4 and columns 3, 4, 5
# Out:
#    total_deaths  total_recovered  active_cases
# 0        7690.0         162202.0        9375.0
# 1        3497.0         271826.0         251.0
# 2        6875.0         178371.0       80570.0
# 3         153.0          41021.0         982.0
# 4        1900.0          97149.0         145.0

# %%
covid_data.iloc[4:100:10]  # select all the columns of the row, where row index starts from 4, ends at less than 100 and at a step of 10.
# Out:
#                    country          continent  total_confirmed  total_deaths  \
# 4                   Angola             Africa            99194        1900.0
# 14                 Bahrain               Asia           576997        1479.0
# 24  Bosnia And Herzegovina             Europe           377511       15778.0
# 34                Cameroon             Africa           119780        1927.0
# 44                   China               Asia           221804        5209.0
# 54                  Cyprus               Asia           477711        1032.0
# 64       Equatorial Guinea             Africa            15910         183.0
# 74        French Polynesia  Australia/Oceania            72821         649.0
# 84              Guadeloupe      North America           140130         854.0
# 94                   India               Asia         43121599      524214.0
#
#     total_recovered  active_cases  serious_or_critical  \
# 4           97149.0         145.0                  NaN
# 14         569758.0        5760.0                  4.0
# 24              NaN           NaN                  NaN
# 34         117791.0          62.0                 13.0
# 44         210454.0        6141.0                383.0
# 54         124370.0      352309.0                 60.0
# 64          15701.0          26.0                  5.0
# 74              NaN           NaN                  7.0
# 84           2250.0      137026.0                 19.0
# 94       42579693.0       17692.0                698.0
#
#     total_cases_per_1m_population  total_deaths_per_1m_population  \
# 4                            2853                            55.0
# 14                         318491                           816.0
# 24                         116414                          4866.0
# 34                           4312                            69.0
# 44                            154                             4.0
# 54                         390374                           843.0
# 64                          10687                           123.0
# 74                         256473                          2286.0
# 84                         350105                          2134.0
# 94                          30686                           373.0
#
#     total_tests  total_tests_per_1m_population  population
# 4     1499795.0                        43136.0    34769277
# 14    9775981.0                      5396149.0     1811659
# 24    1767199.0                       544957.0     3242823
# 34    1751774.0                        63068.0    27776053
# 44  160000000.0                       111163.0  1439323776
# 54    9477138.0                      7744481.0     1223728
# 64     317211.0                       213068.0     1488778
# 74          NaN                            NaN      283932
# 84     938039.0                      2343627.0      400251
# 94  843836914.0                       600479.0  1405273033

# %%
covid_data.iloc[2:15:3, ::2]  # rows -> 2, 5, 8, 11, 14, columns -> 0, 2, 4, ...
# Out:
#      country  total_confirmed  total_recovered  serious_or_critical  \
# 2    Algeria           265816         178371.0                  6.0
# 5   Anguilla             2984           2916.0                  4.0
# 8    Armenia           422896         412048.0                  NaN
# 11   Austria          4212492        4135885.0                 58.0
# 14   Bahrain           576997         569758.0                  4.0
#
#     total_deaths_per_1m_population  total_tests_per_1m_population
# 2                            152.0                         5093.0
# 5                            590.0                      3368870.0
# 8                           2900.0                      1031834.0
# 11                          2011.0                     20328801.0
# 14                           816.0                      5396149.0

# %% [markdown]
# #### `.loc`

# %%
covid_data_selected = covid_data.loc[0:10, ['country', 'total_confirmed', 'total_deaths']]  

# incase of .loc when specifed rows from a:b then both a and b are included. stop value is included

covid_data_selected
# Out:
#                 country  total_confirmed  total_deaths
# 0           Afghanistan           179267        7690.0
# 1               Albania           275574        3497.0
# 2               Algeria           265816        6875.0
# 3               Andorra            42156         153.0
# 4                Angola            99194        1900.0
# 5              Anguilla             2984           9.0
# 6   Antigua And Barbuda             7721         137.0
# 7             Argentina          9101319      128729.0
# 8               Armenia           422896        8623.0
# 9                 Aruba            35693         213.0
# 10            Australia          6593795        7794.0

# %% [markdown]
# `.iloc` → Integer-position based indexing (Python style)
#
# `.iloc` works exactly like normal Python slicing.  like `list[start : stop]` -> stop is excluded
#
# `.loc` → Label-based indexing (data label semantics)
#
# `.loc` uses actual labels, not positions.
#
# When humans specify labels in real tables, they expect the end label to be included.

# %% [markdown]
# ### Boolean indexing

# %%
covid_data['total_confirmed'] > 500000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: total_confirmed, Length: 226, dtype: bool

# %%
covid_data[covid_data['total_confirmed']>500000]  # returns a dataframe where 'total_confirmed' > 500000
# Out:
#                   country          continent  total_confirmed  total_deaths  \
# 7               Argentina      South America          9101319      128729.0
# 10              Australia  Australia/Oceania          6593795        7794.0
# 11                Austria             Europe          4212492       18303.0
# 12             Azerbaijan               Asia           792638        9709.0
# 14                Bahrain               Asia           576997        1479.0
# ..                    ...                ...              ...           ...
# 214  United Arab Emirates               Asia           902484        2302.0
# 215               Uruguay      South America           902540        7213.0
# 216                   USA      North America         84209473     1026646.0
# 219             Venezuela      South America           522921        5711.0
# 220              Viet Nam               Asia         10696630       43065.0
#
#      total_recovered  active_cases  serious_or_critical  \
# 7          8895999.0       76591.0                372.0
# 10         6199822.0      386179.0                129.0
# 11         4135885.0       58304.0                 58.0
# 12          782869.0          60.0                  NaN
# 14          569758.0        5760.0                  4.0
# ..               ...           ...                  ...
# 214         886128.0       14054.0                  NaN
# 215         892434.0        2893.0                 18.0
# 216       81244260.0     1938567.0               1941.0
# 219         516170.0        1040.0                230.0
# 220        9355040.0     1298525.0                340.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 7                           197992                          2800.0
# 10                          253112                           299.0
# 11                          462804                          2011.0
# 12                           76885                           942.0
# 14                          318491                           816.0
# ..                             ...                             ...
# 214                          89240                           228.0
# 215                         258152                          2063.0
# 216                         251659                          3068.0
# 219                          18487                           202.0
# 220                         108080                           435.0
#
#       total_tests  total_tests_per_1m_population  population
# 7    3.571607e+07                       776974.0    45968174
# 10   7.088560e+07                      2721042.0    26050899
# 11   1.850349e+08                     20328801.0     9102106
# 12   6.838458e+06                       663324.0    10309383
# 14   9.775981e+06                      5396149.0     1811659
# ..            ...                            ...         ...
# 214  1.591033e+08                     15732628.0    10112950
# 215  6.114822e+06                      1749015.0     3496151
# 216  1.016883e+09                      3038939.0   334617623
# 219  3.359014e+06                       118752.0    28285909
# 220  8.581148e+07                       867048.0    98969721
#
# [87 rows x 12 columns]

# %%
covid_data[(covid_data['total_confirmed']>500000) & (covid_data['total_deaths']>200000)]
# Out:
#     country      continent  total_confirmed  total_deaths  total_recovered  \
# 26   Brazil  South America         30682094      664920.0       29718402.0
# 94    India           Asia         43121599      524214.0       42579693.0
# 131  Mexico  North America          5745652      324465.0        5044893.0
# 158    Peru  South America          3571919      213023.0              NaN
# 165  Russia         Europe         18260293      377670.0       17647179.0
# 216     USA  North America         84209473     1026646.0       81244260.0
#
#      active_cases  serious_or_critical  total_cases_per_1m_population  \
# 26       298772.0               8318.0                         142460
# 94        17692.0                698.0                          30686
# 131      376294.0               4798.0                          43708
# 158           NaN                248.0                         105593
# 165      235444.0               2300.0                         125027
# 216     1938567.0               1941.0                         251659
#
#      total_deaths_per_1m_population   total_tests  \
# 26                           3087.0  6.377617e+07
# 94                            373.0  8.438369e+08
# 131                          2468.0  1.585549e+07
# 158                          6297.0  3.022687e+07
# 165                          2586.0  2.734000e+08
# 216                          3068.0  1.016883e+09
#
#      total_tests_per_1m_population  population
# 26                        296119.0   215373503
# 94                        600479.0  1405273033
# 131                       120615.0   131455607
# 158                       893567.0    33827210
# 165                      1871949.0   146050996
# 216                      3038939.0   334617623

# %%
covid_data_europe = covid_data[covid_data['continent']=='Europe']

# %%
covid_data_europe
# Out:
#                     country continent  total_confirmed  total_deaths  \
# 1                   Albania    Europe           275574        3497.0
# 3                   Andorra    Europe            42156         153.0
# 11                  Austria    Europe          4212492       18303.0
# 17                  Belarus    Europe           982867        6978.0
# 18                  Belgium    Europe          4116397       31613.0
# 24   Bosnia And Herzegovina    Europe           377511       15778.0
# 29                 Bulgaria    Europe          1161504       37045.0
# 40          Channel Islands    Europe            75275         173.0
# 51                  Croatia    Europe          1131450       15930.0
# 55           Czech Republic    Europe          3915847       40245.0
# 57                  Denmark    Europe          2976667        6287.0
# 66                  Estonia    Europe           573922        2556.0
# 68           Faeroe Islands    Europe            34658          28.0
# 71                  Finland    Europe          1069740        4284.0
# 72                   France    Europe         29160802      147257.0
# 78                  Germany    Europe         25780226      137919.0
# 80                Gibraltar    Europe            18129         102.0
# 81                   Greece    Europe          3392575       29547.0
# 90                 Holy See    Europe               29           NaN
# 92                  Hungary    Europe          1909948       46343.0
# 93                  Iceland    Europe           186545         120.0
# 98                  Ireland    Europe          1535451        7203.0
# 99              Isle Of Man    Europe            28416         105.0
# 101                   Italy    Europe         17057873      165244.0
# 111                  Latvia    Europe           825699        5798.0
# 116           Liechtenstein    Europe            17347          84.0
# 117               Lithuania    Europe          1060619        9127.0
# 118              Luxembourg    Europe           244182        1073.0
# 119               Macedonia    Europe           310684        9289.0
# 125                   Malta    Europe            93508         713.0
# 133                 Moldova    Europe           516986       11489.0
# 134                  Monaco    Europe            12004          54.0
# 136              Montenegro    Europe           236277        2719.0
# 144             Netherlands    Europe          8067116       22292.0
# 151                  Norway    Europe          1429717        3061.0
# 160                  Poland    Europe          6003436      116207.0
# 161                Portugal    Europe          4066674       22583.0
# 164                 Romania    Europe          2903072       65612.0
# 165                  Russia    Europe         18260293      377670.0
# 175              San Marino    Europe            16852         115.0
# 179                  Serbia    Europe          2012836       16049.0
# 184                Slovakia    Europe          1787093       20041.0
# 185                Slovenia    Europe          1019468        6622.0
# 191                   Spain    Europe         12127122      105444.0
# 197                  Sweden    Europe          2504894       18864.0
# 198             Switzerland    Europe          3631881       13882.0
# 212                      UK    Europe         22159805      176708.0
# 213                 Ukraine    Europe          5006460      108449.0
#
#      total_recovered  active_cases  serious_or_critical  \
# 1           271826.0         251.0                  2.0
# 3            41021.0         982.0                 14.0
# 11         4135885.0       58304.0                 58.0
# 17               NaN           NaN                  NaN
# 18         3941350.0      143434.0                117.0
# 24               NaN           NaN                  NaN
# 29         1014302.0      110157.0                 54.0
# 40           74574.0         528.0                  NaN
# 51         1111405.0        4115.0                 15.0
# 55         3871654.0        3948.0                 14.0
# 57         2960386.0        9994.0                 12.0
# 66          514836.0       56530.0                  3.0
# 68            7693.0       26937.0                  5.0
# 71               NaN           NaN                 21.0
# 72        28156674.0      856871.0               1329.0
# 78        23956700.0     1685607.0               1279.0
# 80           16579.0        1448.0                  NaN
# 81         3306014.0       57014.0                176.0
# 90              29.0           0.0                  NaN
# 92         1821435.0       42170.0                 29.0
# 93               NaN           NaN                  NaN
# 98         1499879.0       28369.0                 28.0
# 99           26794.0        1517.0                  NaN
# 101       15894511.0      998118.0                347.0
# 111         816253.0        3648.0                  6.0
# 116          17192.0          71.0                  1.0
# 117        1032609.0       18883.0                 11.0
# 118         235939.0        7170.0                  NaN
# 119         300761.0         634.0                  NaN
# 125          90076.0        2719.0                  4.0
# 133         504142.0        1355.0                 49.0
# 134          11866.0          84.0                  4.0
# 136         232955.0         603.0                  6.0
# 144        7989151.0       55673.0                 55.0
# 151              NaN           NaN                 20.0
# 160        5335112.0      552117.0                981.0
# 161              NaN           NaN                 61.0
# 164              NaN           NaN                138.0
# 165       17647179.0      235444.0               2300.0
# 175          16454.0         283.0                  4.0
# 179        1988209.0        8578.0                 12.0
# 184        1761664.0        5388.0                 30.0
# 185        1003559.0        9287.0                  9.0
# 191       11548089.0      473589.0                339.0
# 197        2477725.0        8305.0                  9.0
# 198        3551493.0       66506.0                 78.0
# 212       21677896.0      305201.0                253.0
# 213              NaN           NaN                177.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 1                            95954                          1218.0
# 3                           543983                          1974.0
# 11                          462804                          2011.0
# 17                          104078                           739.0
# 18                          352324                          2706.0
# 24                          116414                          4866.0
# 29                          169536                          5407.0
# 40                          425648                           978.0
# 51                          278811                          3925.0
# 55                          364401                          3745.0
# 57                          510561                          1078.0
# 66                          432106                          1924.0
# 68                          704302                           569.0
# 71                          192512                           771.0
# 72                          444914                          2247.0
# 78                          305877                          1636.0
# 80                          538400                          3029.0
# 81                          328475                          2861.0
# 90                           36025                             NaN
# 92                          198649                          4820.0
# 93                          540134                           347.0
# 98                          304622                          1429.0
# 99                          330915                          1223.0
# 101                         282901                          2741.0
# 111                         446957                          3139.0
# 116                         452546                          2191.0
# 117                         399994                          3442.0
# 118                         378610                          1664.0
# 119                         149137                          4459.0
# 125                         210730                          1607.0
# 133                         128715                          2860.0
# 134                         301911                          1358.0
# 136                         376109                          4328.0
# 144                         468869                          1296.0
# 151                         259940                           557.0
# 160                         158950                          3077.0
# 161                         400999                          2227.0
# 164                         152803                          3453.0
# 165                         125027                          2586.0
# 175                         494716                          3376.0
# 179                         232112                          1851.0
# 184                         327033                          3667.0
# 185                         490254                          3184.0
# 191                         259190                          2254.0
# 197                         245180                          1846.0
# 198                         414008                          1582.0
# 212                         323264                          2578.0
# 213                         115771                          2508.0
#
#      total_tests  total_tests_per_1m_population  population
# 1      1817530.0                       632857.0     2871945
# 3       249838.0                      3223924.0       77495
# 11   185034905.0                     20328801.0     9102106
# 17    13220483.0                      1399951.0     9443535
# 18    33846023.0                      2896893.0    11683561
# 24     1767199.0                       544957.0     3242823
# 29     9924259.0                      1448573.0     6851060
# 40     1252808.0                      7084095.0      176848
# 51     4838151.0                      1192212.0     4058130
# 55    55323981.0                      5148342.0    10745981
# 57   127345763.0                     21842472.0     5830190
# 66     3345340.0                      2518710.0     1328196
# 68      778000.0                     15810116.0       49209
# 71    10832080.0                      1949355.0     5556750
# 72   271490188.0                      4142201.0    65542502
# 78   122332384.0                      1451450.0    84282880
# 80      534283.0                     15867278.0       33672
# 81    81233888.0                      7865209.0    10328255
# 90           NaN                            NaN         805
# 92    11394556.0                      1185122.0     9614673
# 93     2264004.0                      6555338.0      345368
# 98    12144747.0                      2409429.0     5040509
# 99      150753.0                      1755575.0       85871
# 101  217853667.0                      3613054.0    60296265
# 111    7217715.0                      3907005.0     1847378
# 116     102174.0                      2665501.0       38332
# 117    9954903.0                      3754317.0     2651588
# 118    4248188.0                      6586920.0      644943
# 119    2034606.0                       976666.0     2083215
# 125    1904970.0                      4293055.0      443733
# 133    3216305.0                       800772.0     4016504
# 134      54960.0                      1382294.0       39760
# 136    2465201.0                      3924142.0      628214
# 144   21107399.0                      1226784.0    17205480
# 151   11002430.0                      2000372.0     5500191
# 160   36224215.0                       959088.0    37769420
# 161   41903714.0                      4131968.0    10141346
# 164   22954921.0                      1208233.0    18998751
# 165  273400000.0                      1871949.0   146050996
# 175     152231.0                      4468970.0       34064
# 179    9596815.0                      1106664.0     8671838
# 184    7127129.0                      1304244.0     5464567
# 185    2656926.0                      1277694.0     2079470
# 191  471036328.0                     10067352.0    46788503
# 197   18553837.0                      1816057.0    10216549
# 198   20927607.0                      2385592.0     8772500
# 212  519264096.0                      7574950.0    68550166
# 213   19521252.0                       451415.0    43244553

# %%
covid_data_europe.shape
# Out:
# (48, 12)

# %% [markdown]
# ### to NumPy arrays

# %%
covid_data_europe['total_confirmed'].values
# Out:
# array([  275574,    42156,  4212492,   982867,  4116397,   377511,
#         1161504,    75275,  1131450,  3915847,  2976667,   573922,
#           34658,  1069740, 29160802, 25780226,    18129,  3392575,
#              29,  1909948,   186545,  1535451,    28416, 17057873,
#          825699,    17347,  1060619,   244182,   310684,    93508,
#          516986,    12004,   236277,  8067116,  1429717,  6003436,
#         4066674,  2903072, 18260293,    16852,  2012836,  1787093,
#         1019468, 12127122,  2504894,  3631881, 22159805,  5006460])

# %%
covid_data_numpy = covid_data_europe.to_numpy()

print(type(covid_data_numpy))
covid_data_numpy.shape
# Out:
# <class 'numpy.ndarray'>
# (48, 12)

# %% [markdown]
# ### unique values

# %%
df = pd.DataFrame({'market': ['A', 'B', 'A', 'B', 'A', 'B'], 
                   'fruits': ['apple', 'apple', 'orange', 'orange', 'guava', 'guava'],
                   'price': [100, 120, 80, 75, 55, 70]})

df
# Out:
#   market  fruits  price
# 0      A   apple    100
# 1      B   apple    120
# 2      A  orange     80
# 3      B  orange     75
# 4      A   guava     55
# 5      B   guava     70

# %%
df['market'].nunique()  # number of unique values
# Out:
# 2

# %%
df['fruits'].nunique()
# Out:
# 3

# %%
df['market'].unique()   # array of unique values
# Out:
# array(['A', 'B'], dtype=object)

# %%
df['fruits'].unique()
# Out:
# array(['apple', 'orange', 'guava'], dtype=object)

# %%
df
# Out:
#   market  fruits  price
# 0      A   apple    100
# 1      B   apple    120
# 2      A  orange     80
# 3      B  orange     75
# 4      A   guava     55
# 5      B   guava     70

# %% [markdown]
# ### iterrows() and items()
#
# `iterrows()`: This method iterates over the rows of a DataFrame, returning an iterator that yields pairs of (index, row) for each row. The index is the row label, and the row is a Series object containing the data for that row.

# %%
for index, row in df.iterrows():
    print(index, row['market'], row['fruits'], row['price'])
# Out:
# 0 A apple 100
# 1 B apple 120
# 2 A orange 80
# 3 B orange 75
# 4 A guava 55
# 5 B guava 70

# %% [markdown]
# `items()`: This method iterates over the columns of a DataFrame, returning an iterator that yields pairs of (column name, column data) for each column. The column name is a string, and the column data is a Series object containing the data for that column.
#
# `iteritems()`: This was depricated in pandas 2.0

# %%
for column_name, column_data in df.items():
    print(column_name, column_data.values)
# Out:
# market ['A' 'B' 'A' 'B' 'A' 'B']
# fruits ['apple' 'apple' 'orange' 'orange' 'guava' 'guava']
# price [100 120  80  75  55  70]

# %% [markdown]
# ### value_counts()
#
# The `value_counts()` method operates on a Series. It returns a Series containing the count of unique values in the original Series. By default it sorts the result in descending order and show the most frequent values first.

# %%
data = pd.DataFrame({'name': ['A', 'B', 'C', 'D', 'A', 'C', 'C', 'D', 'C', 'A'],
                     'values': [1, 3, 5, 2, 5, 4, 1, 6, 7, 8]})

data
# Out:
#   name  values
# 0    A       1
# 1    B       3
# 2    C       5
# 3    D       2
# 4    A       5
# 5    C       4
# 6    C       1
# 7    D       6
# 8    C       7
# 9    A       8

# %%
data['name'].value_counts()
# Out:
# name
# C    4
# A    3
# D    2
# B    1
# Name: count, dtype: int64

# %%
data['name'].value_counts(normalize=True)  # normalize by the sum of the series values
# Out:
# name
# C    0.4
# A    0.3
# D    0.2
# B    0.1
# Name: proportion, dtype: float64

# %% [markdown]
# ### Operations on DataFrame

# %% [markdown]
# #### Copying the DataFrame

# %%
covid_data = pd.read_csv("./worldometer_coronavirus_summary_data.csv")

covid_data.head()
# Out:
#        country continent  total_confirmed  total_deaths  total_recovered  \
# 0  Afghanistan      Asia           179267        7690.0         162202.0
# 1      Albania    Europe           275574        3497.0         271826.0
# 2      Algeria    Africa           265816        6875.0         178371.0
# 3      Andorra    Europe            42156         153.0          41021.0
# 4       Angola    Africa            99194        1900.0          97149.0
#
#    active_cases  serious_or_critical  total_cases_per_1m_population  \
# 0        9375.0               1124.0                           4420
# 1         251.0                  2.0                          95954
# 2       80570.0                  6.0                           5865
# 3         982.0                 14.0                         543983
# 4         145.0                  NaN                           2853
#
#    total_deaths_per_1m_population  total_tests  total_tests_per_1m_population  \
# 0                           190.0     951337.0                        23455.0
# 1                          1218.0    1817530.0                       632857.0
# 2                           152.0     230861.0                         5093.0
# 3                          1974.0     249838.0                      3223924.0
# 4                            55.0    1499795.0                        43136.0
#
#    population
# 0    40560636
# 1     2871945
# 2    45325517
# 3       77495
# 4    34769277

# %%
covid_data_copy = covid_data.copy()

# %% [markdown]
# #### Arithmatic operations
#
# Suppose we want to create a column with percentage of total world population

# %%
total_population = sum(covid_data['population'])

total_population
# Out:
# 7899878348

# %%
population_pct = (100 * covid_data['population'] / total_population)

population_pct
# Out:
# 0      0.513434
# 1      0.036354
# 2      0.573750
# 3      0.000981
# 4      0.440124
#          ...
# 221    0.000138
# 222    0.007907
# 223    0.393032
# 224    0.244844
# 225    0.193242
# Name: population, Length: 226, dtype: float64

# %%
sum(population_pct)
# Out:
# 100.0

# %%
covid_data_copy['population_pct'] = population_pct

covid_data_copy
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           179267
# 1                      Albania             Europe           275574
# 2                      Algeria             Africa           265816
# 3                      Andorra             Europe            42156
# 4                       Angola             Africa            99194
# ..                         ...                ...              ...
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          7690.0         162202.0        9375.0               1124.0
# 1          3497.0         271826.0         251.0                  2.0
# 2          6875.0         178371.0       80570.0                  6.0
# 3           153.0          41021.0         982.0                 14.0
# 4          1900.0          97149.0         145.0                  NaN
# ..            ...              ...           ...                  ...
# 221           7.0            438.0           9.0                  NaN
# 222           1.0              9.0           0.0                  NaN
# 223        2149.0           9009.0         661.0                 23.0
# 224        3983.0         315997.0         611.0                  NaN
# 225        5482.0         242417.0        1307.0                 12.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                             4420                           190.0
# 1                            95954                          1218.0
# 2                             5865                           152.0
# 3                           543983                          1974.0
# 4                             2853                            55.0
# ..                             ...                             ...
# 221                          41755                           644.0
# 222                             16                             2.0
# 223                            381                            69.0
# 224                          16575                           206.0
# 225                          16324                           359.0
#
#      total_tests  total_tests_per_1m_population  population  population_pct
# 0       951337.0                        23455.0    40560636        0.513434
# 1      1817530.0                       632857.0     2871945        0.036354
# 2       230861.0                         5093.0    45325517        0.573750
# 3       249838.0                      3223924.0       77495        0.000981
# 4      1499795.0                        43136.0    34769277        0.440124
# ..           ...                            ...         ...             ...
# 221      20508.0                      1886140.0       10873        0.000138
# 222          NaN                            NaN      624681        0.007907
# 223     265253.0                         8543.0    31049015        0.393032
# 224    3452554.0                       178497.0    19342381        0.244844
# 225    2287793.0                       149863.0    15265849        0.193242
#
# [226 rows x 13 columns]

# %%
covid_data_copy[covid_data_copy['country'] == 'China']
# Out:
#    country continent  total_confirmed  total_deaths  total_recovered  \
# 44   China      Asia           221804        5209.0         210454.0
#
#     active_cases  serious_or_critical  total_cases_per_1m_population  \
# 44        6141.0                383.0                            154
#
#     total_deaths_per_1m_population  total_tests  \
# 44                             4.0  160000000.0
#
#     total_tests_per_1m_population  population  population_pct
# 44                       111163.0  1439323776       18.219569

# %%
covid_data_copy[covid_data_copy['country'].isin(['China','India', 'USA'])]
# Out:
#     country      continent  total_confirmed  total_deaths  total_recovered  \
# 44    China           Asia           221804        5209.0         210454.0
# 94    India           Asia         43121599      524214.0       42579693.0
# 216     USA  North America         84209473     1026646.0       81244260.0
#
#      active_cases  serious_or_critical  total_cases_per_1m_population  \
# 44         6141.0                383.0                            154
# 94        17692.0                698.0                          30686
# 216     1938567.0               1941.0                         251659
#
#      total_deaths_per_1m_population   total_tests  \
# 44                              4.0  1.600000e+08
# 94                            373.0  8.438369e+08
# 216                          3068.0  1.016883e+09
#
#      total_tests_per_1m_population  population  population_pct
# 44                        111163.0  1439323776       18.219569
# 94                        600479.0  1405273033       17.788540
# 216                      3038939.0   334617623        4.235731

# %%
covid_data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         226 non-null    object
#  1   continent                       226 non-null    object
#  2   total_confirmed                 226 non-null    int64
#  3   total_deaths                    218 non-null    float64
#  4   total_recovered                 204 non-null    float64
#  5   active_cases                    204 non-null    float64
#  6   serious_or_critical             145 non-null    float64
#  7   total_cases_per_1m_population   226 non-null    int64
#  8   total_deaths_per_1m_population  218 non-null    float64
#  9   total_tests                     212 non-null    float64
#  10  total_tests_per_1m_population   212 non-null    float64
#  11  population                      226 non-null    int64
#  12  population_pct                  226 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 23.1+ KB

# %%
covid_data_copy['total_confirmed_per_1m_population'] = np.round(1000000*covid_data_copy['total_confirmed']/covid_data_copy['population'], 2)

# %%
covid_data_copy[['country','total_confirmed','population','total_confirmed_per_1m_population']]
# Out:
#                        country  total_confirmed  population  \
# 0                  Afghanistan           179267    40560636
# 1                      Albania           275574     2871945
# 2                      Algeria           265816    45325517
# 3                      Andorra            42156       77495
# 4                       Angola            99194    34769277
# ..                         ...              ...         ...
# 221  Wallis And Futuna Islands              454       10873
# 222             Western Sahara               10      624681
# 223                      Yemen            11819    31049015
# 224                     Zambia           320591    19342381
# 225                   Zimbabwe           249206    15265849
#
#      total_confirmed_per_1m_population
# 0                              4419.73
# 1                             95953.79
# 2                              5864.60
# 3                            543983.48
# 4                              2852.92
# ..                                 ...
# 221                           41754.81
# 222                              16.01
# 223                             380.66
# 224                           16574.54
# 225                           16324.41
#
# [226 rows x 4 columns]

# %% [markdown]
# ####  Sorting
#
# Ascending order sorting

# %%
covid_data_copy.sort_values(by='total_confirmed')
# Out:
#             country          continent  total_confirmed  total_deaths  \
# 168    Saint Helena             Africa                2           NaN
# 132      Micronesia  Australia/Oceania                7           NaN
# 142           Nauru  Australia/Oceania                8           NaN
# 150            Niue  Australia/Oceania                9           NaN
# 222  Western Sahara             Africa               10           1.0
# ..              ...                ...              ...           ...
# 78          Germany             Europe         25780226      137919.0
# 72           France             Europe         29160802      147257.0
# 26           Brazil      South America         30682094      664920.0
# 94            India               Asia         43121599      524214.0
# 216             USA      North America         84209473     1026646.0
#
#      total_recovered  active_cases  serious_or_critical  \
# 168              2.0           0.0                  NaN
# 132              1.0           6.0                  NaN
# 142              5.0           3.0                  NaN
# 150              9.0           0.0                  NaN
# 222              9.0           0.0                  NaN
# ..               ...           ...                  ...
# 78        23956700.0     1685607.0               1279.0
# 72        28156674.0      856871.0               1329.0
# 26        29718402.0      298772.0               8318.0
# 94        42579693.0       17692.0                698.0
# 216       81244260.0     1938567.0               1941.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 168                            327                             NaN
# 132                             60                             NaN
# 142                            731                             NaN
# 150                           5464                             NaN
# 222                             16                             2.0
# ..                             ...                             ...
# 78                          305877                          1636.0
# 72                          444914                          2247.0
# 26                          142460                          3087.0
# 94                           30686                           373.0
# 216                         251659                          3068.0
#
#       total_tests  total_tests_per_1m_population  population  population_pct  \
# 168           NaN                            NaN        6111        0.000077
# 132           NaN                            NaN      117269        0.001484
# 142           NaN                            NaN       10951        0.000139
# 150           NaN                            NaN        1647        0.000021
# 222           NaN                            NaN      624681        0.007907
# ..            ...                            ...         ...             ...
# 78   1.223324e+08                      1451450.0    84282880        1.066888
# 72   2.714902e+08                      4142201.0    65542502        0.829665
# 26   6.377617e+07                       296119.0   215373503        2.726289
# 94   8.438369e+08                       600479.0  1405273033       17.788540
# 216  1.016883e+09                      3038939.0   334617623        4.235731
#
#      total_confirmed_per_1m_population
# 168                             327.28
# 132                              59.69
# 142                             730.53
# 150                            5464.48
# 222                              16.01
# ..                                 ...
# 78                           305877.37
# 72                           444914.39
# 26                           142459.93
# 94                            30685.57
# 216                          251658.81
#
# [226 rows x 14 columns]

# %% [markdown]
# Descending order sorting

# %%
covid_data_copy.sort_values(by='total_confirmed',ascending=False)
# Out:
#             country          continent  total_confirmed  total_deaths  \
# 216             USA      North America         84209473     1026646.0
# 94            India               Asia         43121599      524214.0
# 26           Brazil      South America         30682094      664920.0
# 72           France             Europe         29160802      147257.0
# 78          Germany             Europe         25780226      137919.0
# ..              ...                ...              ...           ...
# 222  Western Sahara             Africa               10           1.0
# 150            Niue  Australia/Oceania                9           NaN
# 142           Nauru  Australia/Oceania                8           NaN
# 132      Micronesia  Australia/Oceania                7           NaN
# 168    Saint Helena             Africa                2           NaN
#
#      total_recovered  active_cases  serious_or_critical  \
# 216       81244260.0     1938567.0               1941.0
# 94        42579693.0       17692.0                698.0
# 26        29718402.0      298772.0               8318.0
# 72        28156674.0      856871.0               1329.0
# 78        23956700.0     1685607.0               1279.0
# ..               ...           ...                  ...
# 222              9.0           0.0                  NaN
# 150              9.0           0.0                  NaN
# 142              5.0           3.0                  NaN
# 132              1.0           6.0                  NaN
# 168              2.0           0.0                  NaN
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 216                         251659                          3068.0
# 94                           30686                           373.0
# 26                          142460                          3087.0
# 72                          444914                          2247.0
# 78                          305877                          1636.0
# ..                             ...                             ...
# 222                             16                             2.0
# 150                           5464                             NaN
# 142                            731                             NaN
# 132                             60                             NaN
# 168                            327                             NaN
#
#       total_tests  total_tests_per_1m_population  population  population_pct  \
# 216  1.016883e+09                      3038939.0   334617623        4.235731
# 94   8.438369e+08                       600479.0  1405273033       17.788540
# 26   6.377617e+07                       296119.0   215373503        2.726289
# 72   2.714902e+08                      4142201.0    65542502        0.829665
# 78   1.223324e+08                      1451450.0    84282880        1.066888
# ..            ...                            ...         ...             ...
# 222           NaN                            NaN      624681        0.007907
# 150           NaN                            NaN        1647        0.000021
# 142           NaN                            NaN       10951        0.000139
# 132           NaN                            NaN      117269        0.001484
# 168           NaN                            NaN        6111        0.000077
#
#      total_confirmed_per_1m_population
# 216                          251658.81
# 94                            30685.57
# 26                           142459.93
# 72                           444914.39
# 78                           305877.37
# ..                                 ...
# 222                              16.01
# 150                            5464.48
# 142                             730.53
# 132                              59.69
# 168                             327.28
#
# [226 rows x 14 columns]

# %%
covid_data_copy.sort_values(by='total_confirmed_per_1m_population',ascending=False)
# Out:
#               country          continent  total_confirmed  total_deaths  \
# 68     Faeroe Islands             Europe            34658          28.0
# 3             Andorra             Europe            42156         153.0
# 93            Iceland             Europe           186545         120.0
# 80          Gibraltar             Europe            18129         102.0
# 57            Denmark             Europe          2976667        6287.0
# ..                ...                ...              ...           ...
# 126  Marshall Islands  Australia/Oceania               17           NaN
# 44              China               Asia           221804        5209.0
# 43    China Macao Sar               Asia               82           NaN
# 132        Micronesia  Australia/Oceania                7           NaN
# 222    Western Sahara             Africa               10           1.0
#
#      total_recovered  active_cases  serious_or_critical  \
# 68            7693.0       26937.0                  5.0
# 3            41021.0         982.0                 14.0
# 93               NaN           NaN                  NaN
# 80           16579.0        1448.0                  NaN
# 57         2960386.0        9994.0                 12.0
# ..               ...           ...                  ...
# 126             14.0           3.0                  NaN
# 44          210454.0        6141.0                383.0
# 43              82.0           0.0                  NaN
# 132              1.0           6.0                  NaN
# 222              9.0           0.0                  NaN
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 68                          704302                           569.0
# 3                           543983                          1974.0
# 93                          540134                           347.0
# 80                          538400                          3029.0
# 57                          510561                          1078.0
# ..                             ...                             ...
# 126                            284                             NaN
# 44                             154                             4.0
# 43                             123                             NaN
# 132                             60                             NaN
# 222                             16                             2.0
#
#      total_tests  total_tests_per_1m_population  population  population_pct  \
# 68      778000.0                     15810116.0       49209        0.000623
# 3       249838.0                      3223924.0       77495        0.000981
# 93     2264004.0                      6555338.0      345368        0.004372
# 80      534283.0                     15867278.0       33672        0.000426
# 57   127345763.0                     21842472.0     5830190        0.073801
# ..           ...                            ...         ...             ...
# 126          NaN                            NaN       59934        0.000759
# 44   160000000.0                       111163.0  1439323776       18.219569
# 43        5375.0                         8073.0      665819        0.008428
# 132          NaN                            NaN      117269        0.001484
# 222          NaN                            NaN      624681        0.007907
#
#      total_confirmed_per_1m_population
# 68                           704302.06
# 3                            543983.48
# 93                           540134.00
# 80                           538399.86
# 57                           510560.89
# ..                                 ...
# 126                             283.65
# 44                              154.10
# 43                              123.16
# 132                              59.69
# 222                              16.01
#
# [226 rows x 14 columns]

# %%
covid_data_copy.sort_values(by='total_confirmed_per_1m_population',ascending=False).loc[2, "total_deaths"]
# Out:
# np.float64(6875.0)

# %%
covid_data_copy.sort_values(by='total_confirmed',ascending=False).reset_index()
# Out:
#      index         country          continent  total_confirmed  total_deaths  \
# 0      216             USA      North America         84209473     1026646.0
# 1       94           India               Asia         43121599      524214.0
# 2       26          Brazil      South America         30682094      664920.0
# 3       72          France             Europe         29160802      147257.0
# 4       78         Germany             Europe         25780226      137919.0
# ..     ...             ...                ...              ...           ...
# 221    222  Western Sahara             Africa               10           1.0
# 222    150            Niue  Australia/Oceania                9           NaN
# 223    142           Nauru  Australia/Oceania                8           NaN
# 224    132      Micronesia  Australia/Oceania                7           NaN
# 225    168    Saint Helena             Africa                2           NaN
#
#      total_recovered  active_cases  serious_or_critical  \
# 0         81244260.0     1938567.0               1941.0
# 1         42579693.0       17692.0                698.0
# 2         29718402.0      298772.0               8318.0
# 3         28156674.0      856871.0               1329.0
# 4         23956700.0     1685607.0               1279.0
# ..               ...           ...                  ...
# 221              9.0           0.0                  NaN
# 222              9.0           0.0                  NaN
# 223              5.0           3.0                  NaN
# 224              1.0           6.0                  NaN
# 225              2.0           0.0                  NaN
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                           251659                          3068.0
# 1                            30686                           373.0
# 2                           142460                          3087.0
# 3                           444914                          2247.0
# 4                           305877                          1636.0
# ..                             ...                             ...
# 221                             16                             2.0
# 222                           5464                             NaN
# 223                            731                             NaN
# 224                             60                             NaN
# 225                            327                             NaN
#
#       total_tests  total_tests_per_1m_population  population  population_pct  \
# 0    1.016883e+09                      3038939.0   334617623        4.235731
# 1    8.438369e+08                       600479.0  1405273033       17.788540
# 2    6.377617e+07                       296119.0   215373503        2.726289
# 3    2.714902e+08                      4142201.0    65542502        0.829665
# 4    1.223324e+08                      1451450.0    84282880        1.066888
# ..            ...                            ...         ...             ...
# 221           NaN                            NaN      624681        0.007907
# 222           NaN                            NaN        1647        0.000021
# 223           NaN                            NaN       10951        0.000139
# 224           NaN                            NaN      117269        0.001484
# 225           NaN                            NaN        6111        0.000077
#
#      total_confirmed_per_1m_population
# 0                            251658.81
# 1                             30685.57
# 2                            142459.93
# 3                            444914.39
# 4                            305877.37
# ..                                 ...
# 221                              16.01
# 222                            5464.48
# 223                             730.53
# 224                              59.69
# 225                             327.28
#
# [226 rows x 15 columns]

# %%
covid_data_copy.sort_values(by='total_confirmed',ascending=False).reset_index(drop=True)
# Out:
#             country          continent  total_confirmed  total_deaths  \
# 0               USA      North America         84209473     1026646.0
# 1             India               Asia         43121599      524214.0
# 2            Brazil      South America         30682094      664920.0
# 3            France             Europe         29160802      147257.0
# 4           Germany             Europe         25780226      137919.0
# ..              ...                ...              ...           ...
# 221  Western Sahara             Africa               10           1.0
# 222            Niue  Australia/Oceania                9           NaN
# 223           Nauru  Australia/Oceania                8           NaN
# 224      Micronesia  Australia/Oceania                7           NaN
# 225    Saint Helena             Africa                2           NaN
#
#      total_recovered  active_cases  serious_or_critical  \
# 0         81244260.0     1938567.0               1941.0
# 1         42579693.0       17692.0                698.0
# 2         29718402.0      298772.0               8318.0
# 3         28156674.0      856871.0               1329.0
# 4         23956700.0     1685607.0               1279.0
# ..               ...           ...                  ...
# 221              9.0           0.0                  NaN
# 222              9.0           0.0                  NaN
# 223              5.0           3.0                  NaN
# 224              1.0           6.0                  NaN
# 225              2.0           0.0                  NaN
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                           251659                          3068.0
# 1                            30686                           373.0
# 2                           142460                          3087.0
# 3                           444914                          2247.0
# 4                           305877                          1636.0
# ..                             ...                             ...
# 221                             16                             2.0
# 222                           5464                             NaN
# 223                            731                             NaN
# 224                             60                             NaN
# 225                            327                             NaN
#
#       total_tests  total_tests_per_1m_population  population  population_pct  \
# 0    1.016883e+09                      3038939.0   334617623        4.235731
# 1    8.438369e+08                       600479.0  1405273033       17.788540
# 2    6.377617e+07                       296119.0   215373503        2.726289
# 3    2.714902e+08                      4142201.0    65542502        0.829665
# 4    1.223324e+08                      1451450.0    84282880        1.066888
# ..            ...                            ...         ...             ...
# 221           NaN                            NaN      624681        0.007907
# 222           NaN                            NaN        1647        0.000021
# 223           NaN                            NaN       10951        0.000139
# 224           NaN                            NaN      117269        0.001484
# 225           NaN                            NaN        6111        0.000077
#
#      total_confirmed_per_1m_population
# 0                            251658.81
# 1                             30685.57
# 2                            142459.93
# 3                            444914.39
# 4                            305877.37
# ..                                 ...
# 221                              16.01
# 222                            5464.48
# 223                             730.53
# 224                              59.69
# 225                             327.28
#
# [226 rows x 14 columns]

# %%
covid_data_copy.sort_values(by=['population','total_confirmed'],ascending=False)
# Out:
#                        country          continent  total_confirmed  \
# 44                       China               Asia           221804
# 94                       India               Asia         43121599
# 216                        USA      North America         84209473
# 95                   Indonesia               Asia          6050776
# 153                   Pakistan               Asia          1529249
# ..                         ...                ...              ...
# 172  Saint Pierre And Miquelon      North America             2739
# 137                 Montserrat      North America              747
# 69   Falkland Islands Malvinas      South America             1126
# 150                       Niue  Australia/Oceania                9
# 90                    Holy See             Europe               29
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 44         5209.0         210454.0        6141.0                383.0
# 94       524214.0       42579693.0       17692.0                698.0
# 216     1026646.0       81244260.0     1938567.0               1941.0
# 95       156458.0        5889534.0        4784.0               2771.0
# 153       30376.0        1494141.0        4732.0                109.0
# ..            ...              ...           ...                  ...
# 172           1.0           2449.0         289.0                  1.0
# 137           2.0            390.0         355.0                  NaN
# 69            NaN              NaN           NaN                  NaN
# 150           NaN              9.0           0.0                  NaN
# 90            NaN             29.0           0.0                  NaN
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 44                             154                             4.0
# 94                           30686                           373.0
# 216                         251659                          3068.0
# 95                           21694                           561.0
# 153                           6681                           133.0
# ..                             ...                             ...
# 172                         477095                           174.0
# 137                         149460                           400.0
# 69                          306896                             NaN
# 150                           5464                             NaN
# 90                           36025                             NaN
#
#       total_tests  total_tests_per_1m_population  population  population_pct  \
# 44   1.600000e+08                       111163.0  1439323776       18.219569
# 94   8.438369e+08                       600479.0  1405273033       17.788540
# 216  1.016883e+09                      3038939.0   334617623        4.235731
# 95   9.724539e+07                       348662.0   278910317        3.530565
# 153  2.835045e+07                       123867.0   228878790        2.897244
# ..            ...                            ...         ...             ...
# 172  2.368700e+04                      4125936.0        5741        0.000073
# 137  1.123800e+04                      2248499.0        4998        0.000063
# 69   8.632000e+03                      2352685.0        3669        0.000046
# 150           NaN                            NaN        1647        0.000021
# 90            NaN                            NaN         805        0.000010
#
#      total_confirmed_per_1m_population
# 44                              154.10
# 94                            30685.57
# 216                          251658.81
# 95                            21694.34
# 153                            6681.48
# ..                                 ...
# 172                          477094.58
# 137                          149459.78
# 69                           306895.61
# 150                            5464.48
# 90                            36024.84
#
# [226 rows x 14 columns]

# %%
# Sort the dataframe using population percentage in descending order and reset index with drop=True

new_df = covid_data_copy.sort_values(by="population_pct", ascending=False).reset_index(drop=True)

new_df
# Out:
#                        country          continent  total_confirmed  \
# 0                        China               Asia           221804
# 1                        India               Asia         43121599
# 2                          USA      North America         84209473
# 3                    Indonesia               Asia          6050776
# 4                     Pakistan               Asia          1529249
# ..                         ...                ...              ...
# 221  Saint Pierre And Miquelon      North America             2739
# 222                 Montserrat      North America              747
# 223  Falkland Islands Malvinas      South America             1126
# 224                       Niue  Australia/Oceania                9
# 225                   Holy See             Europe               29
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          5209.0         210454.0        6141.0                383.0
# 1        524214.0       42579693.0       17692.0                698.0
# 2       1026646.0       81244260.0     1938567.0               1941.0
# 3        156458.0        5889534.0        4784.0               2771.0
# 4         30376.0        1494141.0        4732.0                109.0
# ..            ...              ...           ...                  ...
# 221           1.0           2449.0         289.0                  1.0
# 222           2.0            390.0         355.0                  NaN
# 223           NaN              NaN           NaN                  NaN
# 224           NaN              9.0           0.0                  NaN
# 225           NaN             29.0           0.0                  NaN
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                              154                             4.0
# 1                            30686                           373.0
# 2                           251659                          3068.0
# 3                            21694                           561.0
# 4                             6681                           133.0
# ..                             ...                             ...
# 221                         477095                           174.0
# 222                         149460                           400.0
# 223                         306896                             NaN
# 224                           5464                             NaN
# 225                          36025                             NaN
#
#       total_tests  total_tests_per_1m_population  population  population_pct  \
# 0    1.600000e+08                       111163.0  1439323776       18.219569
# 1    8.438369e+08                       600479.0  1405273033       17.788540
# 2    1.016883e+09                      3038939.0   334617623        4.235731
# 3    9.724539e+07                       348662.0   278910317        3.530565
# 4    2.835045e+07                       123867.0   228878790        2.897244
# ..            ...                            ...         ...             ...
# 221  2.368700e+04                      4125936.0        5741        0.000073
# 222  1.123800e+04                      2248499.0        4998        0.000063
# 223  8.632000e+03                      2352685.0        3669        0.000046
# 224           NaN                            NaN        1647        0.000021
# 225           NaN                            NaN         805        0.000010
#
#      total_confirmed_per_1m_population
# 0                               154.10
# 1                             30685.57
# 2                            251658.81
# 3                             21694.34
# 4                              6681.48
# ..                                 ...
# 221                          477094.58
# 222                          149459.78
# 223                          306895.61
# 224                            5464.48
# 225                           36024.84
#
# [226 rows x 14 columns]

# %%
new_df.tail()['country'] # Least populated 5 countries
# Out:
# 221    Saint Pierre And Miquelon
# 222                   Montserrat
# 223    Falkland Islands Malvinas
# 224                         Niue
# 225                     Holy See
# Name: country, dtype: object

# %% [markdown]
# ### inplace operation

# %%
df.sort_values(by='price', ascending=False, inplace=True)

# %%
df
# Out:
#   market  fruits  price
# 1      B   apple    120
# 0      A   apple    100
# 2      A  orange     80
# 3      B  orange     75
# 5      B   guava     70
# 4      A   guava     55

# %% [markdown]
# #### Filter

# %%
covid_data[['country','continent','population']]
# Out:
#                        country          continent  population
# 0                  Afghanistan               Asia    40560636
# 1                      Albania             Europe     2871945
# 2                      Algeria             Africa    45325517
# 3                      Andorra             Europe       77495
# 4                       Angola             Africa    34769277
# ..                         ...                ...         ...
# 221  Wallis And Futuna Islands  Australia/Oceania       10873
# 222             Western Sahara             Africa      624681
# 223                      Yemen               Asia    31049015
# 224                     Zambia             Africa    19342381
# 225                   Zimbabwe             Africa    15265849
#
# [226 rows x 3 columns]

# %%
covid_data_copy.filter(items=['country','continent','population'])
# Out:
#                        country          continent  population
# 0                  Afghanistan               Asia    40560636
# 1                      Albania             Europe     2871945
# 2                      Algeria             Africa    45325517
# 3                      Andorra             Europe       77495
# 4                       Angola             Africa    34769277
# ..                         ...                ...         ...
# 221  Wallis And Futuna Islands  Australia/Oceania       10873
# 222             Western Sahara             Africa      624681
# 223                      Yemen               Asia    31049015
# 224                     Zambia             Africa    19342381
# 225                   Zimbabwe             Africa    15265849
#
# [226 rows x 3 columns]

# %%
covid_data_copy.columns
# Out:
# Index(['country', 'continent', 'total_confirmed', 'total_deaths',
#        'total_recovered', 'active_cases', 'serious_or_critical',
#        'total_cases_per_1m_population', 'total_deaths_per_1m_population',
#        'total_tests', 'total_tests_per_1m_population', 'population',
#        'population_pct', 'total_confirmed_per_1m_population'],
#       dtype='object')

# %%
covid_data_copy.filter(like='population',axis=1)   # By default axis=1
# Out:
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                             4420                           190.0
# 1                            95954                          1218.0
# 2                             5865                           152.0
# 3                           543983                          1974.0
# 4                             2853                            55.0
# ..                             ...                             ...
# 221                          41755                           644.0
# 222                             16                             2.0
# 223                            381                            69.0
# 224                          16575                           206.0
# 225                          16324                           359.0
#
#      total_tests_per_1m_population  population  population_pct  \
# 0                          23455.0    40560636        0.513434
# 1                         632857.0     2871945        0.036354
# 2                           5093.0    45325517        0.573750
# 3                        3223924.0       77495        0.000981
# 4                          43136.0    34769277        0.440124
# ..                             ...         ...             ...
# 221                      1886140.0       10873        0.000138
# 222                            NaN      624681        0.007907
# 223                         8543.0    31049015        0.393032
# 224                       178497.0    19342381        0.244844
# 225                       149863.0    15265849        0.193242
#
#      total_confirmed_per_1m_population
# 0                              4419.73
# 1                             95953.79
# 2                              5864.60
# 3                            543983.48
# 4                              2852.92
# ..                                 ...
# 221                           41754.81
# 222                              16.01
# 223                             380.66
# 224                           16574.54
# 225                           16324.41
#
# [226 rows x 6 columns]

# %%
covid_data_copy.filter(like='deaths', axis=1)
# Out:
#      total_deaths  total_deaths_per_1m_population
# 0          7690.0                           190.0
# 1          3497.0                          1218.0
# 2          6875.0                           152.0
# 3           153.0                          1974.0
# 4          1900.0                            55.0
# ..            ...                             ...
# 221           7.0                           644.0
# 222           1.0                             2.0
# 223        2149.0                            69.0
# 224        3983.0                           206.0
# 225        5482.0                           359.0
#
# [226 rows x 2 columns]

# %% [markdown]
# #### Query
#
# SQL like queries

# %%
covid_data.query("continent == 'Europe'")
# Out:
#                     country continent  total_confirmed  total_deaths  \
# 1                   Albania    Europe           275574        3497.0
# 3                   Andorra    Europe            42156         153.0
# 11                  Austria    Europe          4212492       18303.0
# 17                  Belarus    Europe           982867        6978.0
# 18                  Belgium    Europe          4116397       31613.0
# 24   Bosnia And Herzegovina    Europe           377511       15778.0
# 29                 Bulgaria    Europe          1161504       37045.0
# 40          Channel Islands    Europe            75275         173.0
# 51                  Croatia    Europe          1131450       15930.0
# 55           Czech Republic    Europe          3915847       40245.0
# 57                  Denmark    Europe          2976667        6287.0
# 66                  Estonia    Europe           573922        2556.0
# 68           Faeroe Islands    Europe            34658          28.0
# 71                  Finland    Europe          1069740        4284.0
# 72                   France    Europe         29160802      147257.0
# 78                  Germany    Europe         25780226      137919.0
# 80                Gibraltar    Europe            18129         102.0
# 81                   Greece    Europe          3392575       29547.0
# 90                 Holy See    Europe               29           NaN
# 92                  Hungary    Europe          1909948       46343.0
# 93                  Iceland    Europe           186545         120.0
# 98                  Ireland    Europe          1535451        7203.0
# 99              Isle Of Man    Europe            28416         105.0
# 101                   Italy    Europe         17057873      165244.0
# 111                  Latvia    Europe           825699        5798.0
# 116           Liechtenstein    Europe            17347          84.0
# 117               Lithuania    Europe          1060619        9127.0
# 118              Luxembourg    Europe           244182        1073.0
# 119               Macedonia    Europe           310684        9289.0
# 125                   Malta    Europe            93508         713.0
# 133                 Moldova    Europe           516986       11489.0
# 134                  Monaco    Europe            12004          54.0
# 136              Montenegro    Europe           236277        2719.0
# 144             Netherlands    Europe          8067116       22292.0
# 151                  Norway    Europe          1429717        3061.0
# 160                  Poland    Europe          6003436      116207.0
# 161                Portugal    Europe          4066674       22583.0
# 164                 Romania    Europe          2903072       65612.0
# 165                  Russia    Europe         18260293      377670.0
# 175              San Marino    Europe            16852         115.0
# 179                  Serbia    Europe          2012836       16049.0
# 184                Slovakia    Europe          1787093       20041.0
# 185                Slovenia    Europe          1019468        6622.0
# 191                   Spain    Europe         12127122      105444.0
# 197                  Sweden    Europe          2504894       18864.0
# 198             Switzerland    Europe          3631881       13882.0
# 212                      UK    Europe         22159805      176708.0
# 213                 Ukraine    Europe          5006460      108449.0
#
#      total_recovered  active_cases  serious_or_critical  \
# 1           271826.0         251.0                  2.0
# 3            41021.0         982.0                 14.0
# 11         4135885.0       58304.0                 58.0
# 17               NaN           NaN                  NaN
# 18         3941350.0      143434.0                117.0
# 24               NaN           NaN                  NaN
# 29         1014302.0      110157.0                 54.0
# 40           74574.0         528.0                  NaN
# 51         1111405.0        4115.0                 15.0
# 55         3871654.0        3948.0                 14.0
# 57         2960386.0        9994.0                 12.0
# 66          514836.0       56530.0                  3.0
# 68            7693.0       26937.0                  5.0
# 71               NaN           NaN                 21.0
# 72        28156674.0      856871.0               1329.0
# 78        23956700.0     1685607.0               1279.0
# 80           16579.0        1448.0                  NaN
# 81         3306014.0       57014.0                176.0
# 90              29.0           0.0                  NaN
# 92         1821435.0       42170.0                 29.0
# 93               NaN           NaN                  NaN
# 98         1499879.0       28369.0                 28.0
# 99           26794.0        1517.0                  NaN
# 101       15894511.0      998118.0                347.0
# 111         816253.0        3648.0                  6.0
# 116          17192.0          71.0                  1.0
# 117        1032609.0       18883.0                 11.0
# 118         235939.0        7170.0                  NaN
# 119         300761.0         634.0                  NaN
# 125          90076.0        2719.0                  4.0
# 133         504142.0        1355.0                 49.0
# 134          11866.0          84.0                  4.0
# 136         232955.0         603.0                  6.0
# 144        7989151.0       55673.0                 55.0
# 151              NaN           NaN                 20.0
# 160        5335112.0      552117.0                981.0
# 161              NaN           NaN                 61.0
# 164              NaN           NaN                138.0
# 165       17647179.0      235444.0               2300.0
# 175          16454.0         283.0                  4.0
# 179        1988209.0        8578.0                 12.0
# 184        1761664.0        5388.0                 30.0
# 185        1003559.0        9287.0                  9.0
# 191       11548089.0      473589.0                339.0
# 197        2477725.0        8305.0                  9.0
# 198        3551493.0       66506.0                 78.0
# 212       21677896.0      305201.0                253.0
# 213              NaN           NaN                177.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 1                            95954                          1218.0
# 3                           543983                          1974.0
# 11                          462804                          2011.0
# 17                          104078                           739.0
# 18                          352324                          2706.0
# 24                          116414                          4866.0
# 29                          169536                          5407.0
# 40                          425648                           978.0
# 51                          278811                          3925.0
# 55                          364401                          3745.0
# 57                          510561                          1078.0
# 66                          432106                          1924.0
# 68                          704302                           569.0
# 71                          192512                           771.0
# 72                          444914                          2247.0
# 78                          305877                          1636.0
# 80                          538400                          3029.0
# 81                          328475                          2861.0
# 90                           36025                             NaN
# 92                          198649                          4820.0
# 93                          540134                           347.0
# 98                          304622                          1429.0
# 99                          330915                          1223.0
# 101                         282901                          2741.0
# 111                         446957                          3139.0
# 116                         452546                          2191.0
# 117                         399994                          3442.0
# 118                         378610                          1664.0
# 119                         149137                          4459.0
# 125                         210730                          1607.0
# 133                         128715                          2860.0
# 134                         301911                          1358.0
# 136                         376109                          4328.0
# 144                         468869                          1296.0
# 151                         259940                           557.0
# 160                         158950                          3077.0
# 161                         400999                          2227.0
# 164                         152803                          3453.0
# 165                         125027                          2586.0
# 175                         494716                          3376.0
# 179                         232112                          1851.0
# 184                         327033                          3667.0
# 185                         490254                          3184.0
# 191                         259190                          2254.0
# 197                         245180                          1846.0
# 198                         414008                          1582.0
# 212                         323264                          2578.0
# 213                         115771                          2508.0
#
#      total_tests  total_tests_per_1m_population  population
# 1      1817530.0                       632857.0     2871945
# 3       249838.0                      3223924.0       77495
# 11   185034905.0                     20328801.0     9102106
# 17    13220483.0                      1399951.0     9443535
# 18    33846023.0                      2896893.0    11683561
# 24     1767199.0                       544957.0     3242823
# 29     9924259.0                      1448573.0     6851060
# 40     1252808.0                      7084095.0      176848
# 51     4838151.0                      1192212.0     4058130
# 55    55323981.0                      5148342.0    10745981
# 57   127345763.0                     21842472.0     5830190
# 66     3345340.0                      2518710.0     1328196
# 68      778000.0                     15810116.0       49209
# 71    10832080.0                      1949355.0     5556750
# 72   271490188.0                      4142201.0    65542502
# 78   122332384.0                      1451450.0    84282880
# 80      534283.0                     15867278.0       33672
# 81    81233888.0                      7865209.0    10328255
# 90           NaN                            NaN         805
# 92    11394556.0                      1185122.0     9614673
# 93     2264004.0                      6555338.0      345368
# 98    12144747.0                      2409429.0     5040509
# 99      150753.0                      1755575.0       85871
# 101  217853667.0                      3613054.0    60296265
# 111    7217715.0                      3907005.0     1847378
# 116     102174.0                      2665501.0       38332
# 117    9954903.0                      3754317.0     2651588
# 118    4248188.0                      6586920.0      644943
# 119    2034606.0                       976666.0     2083215
# 125    1904970.0                      4293055.0      443733
# 133    3216305.0                       800772.0     4016504
# 134      54960.0                      1382294.0       39760
# 136    2465201.0                      3924142.0      628214
# 144   21107399.0                      1226784.0    17205480
# 151   11002430.0                      2000372.0     5500191
# 160   36224215.0                       959088.0    37769420
# 161   41903714.0                      4131968.0    10141346
# 164   22954921.0                      1208233.0    18998751
# 165  273400000.0                      1871949.0   146050996
# 175     152231.0                      4468970.0       34064
# 179    9596815.0                      1106664.0     8671838
# 184    7127129.0                      1304244.0     5464567
# 185    2656926.0                      1277694.0     2079470
# 191  471036328.0                     10067352.0    46788503
# 197   18553837.0                      1816057.0    10216549
# 198   20927607.0                      2385592.0     8772500
# 212  519264096.0                      7574950.0    68550166
# 213   19521252.0                       451415.0    43244553

# %%
covid_data.query("continent == 'Europe' and total_confirmed > 5000000")
# Out:
#          country continent  total_confirmed  total_deaths  total_recovered  \
# 72        France    Europe         29160802      147257.0       28156674.0
# 78       Germany    Europe         25780226      137919.0       23956700.0
# 101        Italy    Europe         17057873      165244.0       15894511.0
# 144  Netherlands    Europe          8067116       22292.0        7989151.0
# 160       Poland    Europe          6003436      116207.0        5335112.0
# 165       Russia    Europe         18260293      377670.0       17647179.0
# 191        Spain    Europe         12127122      105444.0       11548089.0
# 212           UK    Europe         22159805      176708.0       21677896.0
# 213      Ukraine    Europe          5006460      108449.0              NaN
#
#      active_cases  serious_or_critical  total_cases_per_1m_population  \
# 72       856871.0               1329.0                         444914
# 78      1685607.0               1279.0                         305877
# 101      998118.0                347.0                         282901
# 144       55673.0                 55.0                         468869
# 160      552117.0                981.0                         158950
# 165      235444.0               2300.0                         125027
# 191      473589.0                339.0                         259190
# 212      305201.0                253.0                         323264
# 213           NaN                177.0                         115771
#
#      total_deaths_per_1m_population  total_tests  \
# 72                           2247.0  271490188.0
# 78                           1636.0  122332384.0
# 101                          2741.0  217853667.0
# 144                          1296.0   21107399.0
# 160                          3077.0   36224215.0
# 165                          2586.0  273400000.0
# 191                          2254.0  471036328.0
# 212                          2578.0  519264096.0
# 213                          2508.0   19521252.0
#
#      total_tests_per_1m_population  population
# 72                       4142201.0    65542502
# 78                       1451450.0    84282880
# 101                      3613054.0    60296265
# 144                      1226784.0    17205480
# 160                       959088.0    37769420
# 165                      1871949.0   146050996
# 191                     10067352.0    46788503
# 212                      7574950.0    68550166
# 213                       451415.0    43244553

# %%
covid_data.query("continent == 'Europe' and total_confirmed > 5000000").sort_values("total_confirmed",ascending=False).reset_index(drop=True)
# Out:
#        country continent  total_confirmed  total_deaths  total_recovered  \
# 0       France    Europe         29160802      147257.0       28156674.0
# 1      Germany    Europe         25780226      137919.0       23956700.0
# 2           UK    Europe         22159805      176708.0       21677896.0
# 3       Russia    Europe         18260293      377670.0       17647179.0
# 4        Italy    Europe         17057873      165244.0       15894511.0
# 5        Spain    Europe         12127122      105444.0       11548089.0
# 6  Netherlands    Europe          8067116       22292.0        7989151.0
# 7       Poland    Europe          6003436      116207.0        5335112.0
# 8      Ukraine    Europe          5006460      108449.0              NaN
#
#    active_cases  serious_or_critical  total_cases_per_1m_population  \
# 0      856871.0               1329.0                         444914
# 1     1685607.0               1279.0                         305877
# 2      305201.0                253.0                         323264
# 3      235444.0               2300.0                         125027
# 4      998118.0                347.0                         282901
# 5      473589.0                339.0                         259190
# 6       55673.0                 55.0                         468869
# 7      552117.0                981.0                         158950
# 8           NaN                177.0                         115771
#
#    total_deaths_per_1m_population  total_tests  total_tests_per_1m_population  \
# 0                          2247.0  271490188.0                      4142201.0
# 1                          1636.0  122332384.0                      1451450.0
# 2                          2578.0  519264096.0                      7574950.0
# 3                          2586.0  273400000.0                      1871949.0
# 4                          2741.0  217853667.0                      3613054.0
# 5                          2254.0  471036328.0                     10067352.0
# 6                          1296.0   21107399.0                      1226784.0
# 7                          3077.0   36224215.0                       959088.0
# 8                          2508.0   19521252.0                       451415.0
#
#    population
# 0    65542502
# 1    84282880
# 2    68550166
# 3   146050996
# 4    60296265
# 5    46788503
# 6    17205480
# 7    37769420
# 8    43244553

# %%
covid_data.query("continent == 'Europe' and total_confirmed > 5000000")\
          .sort_values("total_confirmed",ascending=False)\
          .reset_index(drop=True)
# Out:
#        country continent  total_confirmed  total_deaths  total_recovered  \
# 0       France    Europe         29160802      147257.0       28156674.0
# 1      Germany    Europe         25780226      137919.0       23956700.0
# 2           UK    Europe         22159805      176708.0       21677896.0
# 3       Russia    Europe         18260293      377670.0       17647179.0
# 4        Italy    Europe         17057873      165244.0       15894511.0
# 5        Spain    Europe         12127122      105444.0       11548089.0
# 6  Netherlands    Europe          8067116       22292.0        7989151.0
# 7       Poland    Europe          6003436      116207.0        5335112.0
# 8      Ukraine    Europe          5006460      108449.0              NaN
#
#    active_cases  serious_or_critical  total_cases_per_1m_population  \
# 0      856871.0               1329.0                         444914
# 1     1685607.0               1279.0                         305877
# 2      305201.0                253.0                         323264
# 3      235444.0               2300.0                         125027
# 4      998118.0                347.0                         282901
# 5      473589.0                339.0                         259190
# 6       55673.0                 55.0                         468869
# 7      552117.0                981.0                         158950
# 8           NaN                177.0                         115771
#
#    total_deaths_per_1m_population  total_tests  total_tests_per_1m_population  \
# 0                          2247.0  271490188.0                      4142201.0
# 1                          1636.0  122332384.0                      1451450.0
# 2                          2578.0  519264096.0                      7574950.0
# 3                          2586.0  273400000.0                      1871949.0
# 4                          2741.0  217853667.0                      3613054.0
# 5                          2254.0  471036328.0                     10067352.0
# 6                          1296.0   21107399.0                      1226784.0
# 7                          3077.0   36224215.0                       959088.0
# 8                          2508.0   19521252.0                       451415.0
#
#    population
# 0    65542502
# 1    84282880
# 2    68550166
# 3   146050996
# 4    60296265
# 5    46788503
# 6    17205480
# 7    37769420
# 8    43244553

# %%
df_e = covid_data.query("continent == 'Europe' and total_confirmed > 5000000")
df_e = df_e.sort_values("total_confirmed",ascending=False).reset_index(drop=True)
df_e
# Out:
#        country continent  total_confirmed  total_deaths  total_recovered  \
# 0       France    Europe         29160802      147257.0       28156674.0
# 1      Germany    Europe         25780226      137919.0       23956700.0
# 2           UK    Europe         22159805      176708.0       21677896.0
# 3       Russia    Europe         18260293      377670.0       17647179.0
# 4        Italy    Europe         17057873      165244.0       15894511.0
# 5        Spain    Europe         12127122      105444.0       11548089.0
# 6  Netherlands    Europe          8067116       22292.0        7989151.0
# 7       Poland    Europe          6003436      116207.0        5335112.0
# 8      Ukraine    Europe          5006460      108449.0              NaN
#
#    active_cases  serious_or_critical  total_cases_per_1m_population  \
# 0      856871.0               1329.0                         444914
# 1     1685607.0               1279.0                         305877
# 2      305201.0                253.0                         323264
# 3      235444.0               2300.0                         125027
# 4      998118.0                347.0                         282901
# 5      473589.0                339.0                         259190
# 6       55673.0                 55.0                         468869
# 7      552117.0                981.0                         158950
# 8           NaN                177.0                         115771
#
#    total_deaths_per_1m_population  total_tests  total_tests_per_1m_population  \
# 0                          2247.0  271490188.0                      4142201.0
# 1                          1636.0  122332384.0                      1451450.0
# 2                          2578.0  519264096.0                      7574950.0
# 3                          2586.0  273400000.0                      1871949.0
# 4                          2741.0  217853667.0                      3613054.0
# 5                          2254.0  471036328.0                     10067352.0
# 6                          1296.0   21107399.0                      1226784.0
# 7                          3077.0   36224215.0                       959088.0
# 8                          2508.0   19521252.0                       451415.0
#
#    population
# 0    65542502
# 1    84282880
# 2    68550166
# 3   146050996
# 4    60296265
# 5    46788503
# 6    17205480
# 7    37769420
# 8    43244553

# %% [markdown]
# **Quick challenge:**
#
# select all the columns in the dataframe which doesn't contain `total` in its name

# %%
s = covid_data_copy.columns

s.str.contains('total')
# Out:
# array([False, False,  True,  True,  True, False, False,  True,  True,
#         True,  True, False, False,  True])

# %%
~s.str.contains('total')
# Out:
# array([ True,  True, False, False, False,  True,  True, False, False,
#        False, False,  True,  True, False])

# %%
s[~s.str.contains('total')]
# Out:
# Index(['country', 'continent', 'active_cases', 'serious_or_critical',
#        'population', 'population_pct'],
#       dtype='object')

# %%
covid_data_copy[s[~s.str.contains('total')]]
# Out:
#                        country          continent  active_cases  \
# 0                  Afghanistan               Asia        9375.0
# 1                      Albania             Europe         251.0
# 2                      Algeria             Africa       80570.0
# 3                      Andorra             Europe         982.0
# 4                       Angola             Africa         145.0
# ..                         ...                ...           ...
# 221  Wallis And Futuna Islands  Australia/Oceania           9.0
# 222             Western Sahara             Africa           0.0
# 223                      Yemen               Asia         661.0
# 224                     Zambia             Africa         611.0
# 225                   Zimbabwe             Africa        1307.0
#
#      serious_or_critical  population  population_pct
# 0                 1124.0    40560636        0.513434
# 1                    2.0     2871945        0.036354
# 2                    6.0    45325517        0.573750
# 3                   14.0       77495        0.000981
# 4                    NaN    34769277        0.440124
# ..                   ...         ...             ...
# 221                  NaN       10873        0.000138
# 222                  NaN      624681        0.007907
# 223                 23.0    31049015        0.393032
# 224                  NaN    19342381        0.244844
# 225                 12.0    15265849        0.193242
#
# [226 rows x 6 columns]

# %%
covid_data_copy.filter(items=s[~s.str.contains('total')])
# Out:
#                        country          continent  active_cases  \
# 0                  Afghanistan               Asia        9375.0
# 1                      Albania             Europe         251.0
# 2                      Algeria             Africa       80570.0
# 3                      Andorra             Europe         982.0
# 4                       Angola             Africa         145.0
# ..                         ...                ...           ...
# 221  Wallis And Futuna Islands  Australia/Oceania           9.0
# 222             Western Sahara             Africa           0.0
# 223                      Yemen               Asia         661.0
# 224                     Zambia             Africa         611.0
# 225                   Zimbabwe             Africa        1307.0
#
#      serious_or_critical  population  population_pct
# 0                 1124.0    40560636        0.513434
# 1                    2.0     2871945        0.036354
# 2                    6.0    45325517        0.573750
# 3                   14.0       77495        0.000981
# 4                    NaN    34769277        0.440124
# ..                   ...         ...             ...
# 221                  NaN       10873        0.000138
# 222                  NaN      624681        0.007907
# 223                 23.0    31049015        0.393032
# 224                  NaN    19342381        0.244844
# 225                 12.0    15265849        0.193242
#
# [226 rows x 6 columns]

# %% [markdown]
# #### Apply and Map
#
# `apply():`
# This function can work on both DataFrames and Series. When used on a DataFrame, it applies a function along an axis (rows or columns).
#
# `map():`
# While map() is primarily designed for Series, it can be used on a DataFrame in a limited way. When applied to a DataFrame, it operates element-wise

# %%
def square(x):
  return x**2

# %%
df = pd.DataFrame(np.array([[1,10,15],[1,5,1],[2,19,0],[8,5,4]]),columns=list('abc'))

df
# Out:
#    a   b   c
# 0  1  10  15
# 1  1   5   1
# 2  2  19   0
# 3  8   5   4

# %%
df.map(square)
# Out:
#     a    b    c
# 0   1  100  225
# 1   1   25    1
# 2   4  361    0
# 3  64   25   16

# %%
df.map(lambda x: x**2)
# Out:
#     a    b    c
# 0   1  100  225
# 1   1   25    1
# 2   4  361    0
# 3  64   25   16

# %%
df.apply(square)  # Applies the function square to the every element of the dataframe
# Out:
#     a    b    c
# 0   1  100  225
# 1   1   25    1
# 2   4  361    0
# 3  64   25   16

# %%
df.apply(lambda x: x**2)
# Out:
#     a    b    c
# 0   1  100  225
# 1   1   25    1
# 2   4  361    0
# 3  64   25   16

# %%
df.map(lambda x: np.sin(x)+np.cos(x))
# Out:
#           a         b         c
# 0  1.381773 -1.383093 -0.109400
# 1  1.381773 -0.675262  1.381773
# 2  0.493151  1.138582  1.000000
# 3  0.843858 -0.675262 -1.410446

# %%
df.apply(lambda x: np.sin(x)+np.cos(x))
# Out:
#           a         b         c
# 0  1.381773 -1.383093 -0.109400
# 1  1.381773 -0.675262  1.381773
# 2  0.493151  1.138582  1.000000
# 3  0.843858 -0.675262 -1.410446

# %%
df
# Out:
#    a   b   c
# 0  1  10  15
# 1  1   5   1
# 2  2  19   0
# 3  8   5   4

# %%
df.apply(max) # by default the axis is 0 -> column wise
# Out:
# a     8
# b    19
# c    15
# dtype: int64

# %%
df.apply(max, axis=1)
# Out:
# 0    15
# 1     5
# 2    19
# 3     8
# dtype: int64

# %%
df.apply(min) # by default the axis is 0 -> column wise
# Out:
# a    1
# b    5
# c    0
# dtype: int64

# %%
df.apply(lambda f: f.max()-f.min())   # by default the axis is 0 -> column wise
# Out:
# a     7
# b    14
# c    15
# dtype: int64

# %%
df
# Out:
#    a   b   c
# 0  1  10  15
# 1  1   5   1
# 2  2  19   0
# 3  8   5   4

# %%
df.apply(lambda f: f.max()-f.min(),axis=1)
# Out:
# 0    14
# 1     4
# 2    19
# 3     4
# dtype: int64

# %% [markdown]
# #### Groupby
#
# A groupby operation involves some combination of the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.

# %%
covid_data_select = covid_data[['continent','total_confirmed','total_deaths','total_recovered']]

# %%
covid_data_select
# Out:
#              continent  total_confirmed  total_deaths  total_recovered
# 0                 Asia           179267        7690.0         162202.0
# 1               Europe           275574        3497.0         271826.0
# 2               Africa           265816        6875.0         178371.0
# 3               Europe            42156         153.0          41021.0
# 4               Africa            99194        1900.0          97149.0
# ..                 ...              ...           ...              ...
# 221  Australia/Oceania              454           7.0            438.0
# 222             Africa               10           1.0              9.0
# 223               Asia            11819        2149.0           9009.0
# 224             Africa           320591        3983.0         315997.0
# 225             Africa           249206        5482.0         242417.0
#
# [226 rows x 4 columns]

# %%
covid_data_select.groupby(['continent'])

# %%
covid_data_select.groupby(['continent']).sum() # This .sum() is called the aggregate function.
# Out:
#                    total_confirmed  total_deaths  total_recovered
# continent
# Africa                    12042400      254319.0       10137200.0
# Asia                     149999659     1427939.0      126145273.0
# Australia/Oceania          7942867       11413.0        7403813.0
# Europe                   194330079     1830655.0      170861871.0
# North America             99625662     1467234.0       94818163.0
# South America             57136485     1296523.0       51031313.0

# %%
covid_data_select.groupby(['continent']).agg({"total_confirmed": 'sum', "total_deaths": 'mean', "total_recovered": 'max'})
# Out:
#                    total_confirmed  total_deaths  total_recovered
# continent
# Africa                    12042400   4461.736842        3708347.0
# Asia                     149999659  29748.729167       42579693.0
# Australia/Oceania          7942867    815.214286        6199822.0
# Europe                   194330079  38950.106383       28156674.0
# North America             99625662  37621.384615       81244260.0
# South America             57136485  99732.538462       29718402.0

# %%
covid_data_select.groupby(['continent']).agg(
    sum_total_confirmed = ('total_confirmed', 'sum'),
    mean_total_deaths = ('total_deaths', 'mean'),
    max_total_recovered = ('total_recovered', 'max')
)
# Out:
#                    sum_total_confirmed  mean_total_deaths  max_total_recovered
# continent
# Africa                        12042400        4461.736842            3708347.0
# Asia                         149999659       29748.729167           42579693.0
# Australia/Oceania              7942867         815.214286            6199822.0
# Europe                       194330079       38950.106383           28156674.0
# North America                 99625662       37621.384615           81244260.0
# South America                 57136485       99732.538462           29718402.0

# %%
def population_bracket(x):
    if x > 10000000:
        return "more than 10m"
    elif x > 5000000:
        return "between 5 to 10m"
    elif x > 1000000:
        return "between 1 to 5m"
    else:
        return "less than 1m"

# %%
population_bracket(1345727819)
# Out:
# 'more than 10m'

# %%
covid_data.columns
# Out:
# Index(['country', 'continent', 'total_confirmed', 'total_deaths',
#        'total_recovered', 'active_cases', 'serious_or_critical',
#        'total_cases_per_1m_population', 'total_deaths_per_1m_population',
#        'total_tests', 'total_tests_per_1m_population', 'population'],
#       dtype='object')

# %%
covid_data_select = covid_data[['population', 'total_confirmed', 'total_deaths']]

covid_data_select['population_bkt'] = covid_data_select['population'].apply(population_bracket)
# Out:
# C:\Users\Sourav Karmakar\AppData\Local\Temp\ipykernel_25644\3860050008.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_data_select['population_bkt'] = covid_data_select['population'].apply(population_bracket)

# %%
covid_data_select
# Out:
#      population  total_confirmed  total_deaths   population_bkt
# 0      40560636           179267        7690.0    more than 10m
# 1       2871945           275574        3497.0  between 1 to 5m
# 2      45325517           265816        6875.0    more than 10m
# 3         77495            42156         153.0     less than 1m
# 4      34769277            99194        1900.0    more than 10m
# ..          ...              ...           ...              ...
# 221       10873              454           7.0     less than 1m
# 222      624681               10           1.0     less than 1m
# 223    31049015            11819        2149.0    more than 10m
# 224    19342381           320591        3983.0    more than 10m
# 225    15265849           249206        5482.0    more than 10m
#
# [226 rows x 4 columns]

# %%
covid_data_select.groupby(['population_bkt']).agg({'population': 'count'})
# Out:
#                   population
# population_bkt
# between 1 to 5m           34
# between 5 to 10m          31
# less than 1m              69
# more than 10m             92

# %% [markdown]
# #### Merge
#
# `merge()`: Combine two Series or DataFrame objects with SQL-style joining. Default is `inner join`.

# %%
employee = pd.DataFrame({'EmpId': [1,2,3,4,7], 'EmpName': ['Sachin', 'Sourav', 'Zaheer', 'Harbhajan', 'Rishika'], 
                         'location': ['Mumbai', 'Kolkata', 'Nagpur', 'Amritsar','Bangalore']})

employee
# Out:
#    EmpId    EmpName   location
# 0      1     Sachin     Mumbai
# 1      2     Sourav    Kolkata
# 2      3     Zaheer     Nagpur
# 3      4  Harbhajan   Amritsar
# 4      7    Rishika  Bangalore

# %%
manager = pd.DataFrame({'EmpId': [1,2,3,4,5,6], 'Manager_Name': ['Kapil', 'Ravi', 'Srinath', 'Prasanna','Padmini','Babu']})

manager
# Out:
#    EmpId Manager_Name
# 0      1        Kapil
# 1      2         Ravi
# 2      3      Srinath
# 3      4     Prasanna
# 4      5      Padmini
# 5      6         Babu

# %% [markdown]
# ![](https://miro.medium.com/max/1200/1*9eH1_7VbTZPZd9jBiGIyNA.png)

# %%
employee
# Out:
#    EmpId    EmpName   location
# 0      1     Sachin     Mumbai
# 1      2     Sourav    Kolkata
# 2      3     Zaheer     Nagpur
# 3      4  Harbhajan   Amritsar
# 4      7    Rishika  Bangalore

# %%
manager
# Out:
#    EmpId Manager_Name
# 0      1        Kapil
# 1      2         Ravi
# 2      3      Srinath
# 3      4     Prasanna
# 4      5      Padmini
# 5      6         Babu

# %%
pd.merge(employee, manager, on='EmpId')   # By default how = 'inner' -> inner join
# Out:
#    EmpId    EmpName  location Manager_Name
# 0      1     Sachin    Mumbai        Kapil
# 1      2     Sourav   Kolkata         Ravi
# 2      3     Zaheer    Nagpur      Srinath
# 3      4  Harbhajan  Amritsar     Prasanna

# %%
pd.merge(employee, manager, on='EmpId', how='inner')
# Out:
#    EmpId    EmpName  location Manager_Name
# 0      1     Sachin    Mumbai        Kapil
# 1      2     Sourav   Kolkata         Ravi
# 2      3     Zaheer    Nagpur      Srinath
# 3      4  Harbhajan  Amritsar     Prasanna

# %%
employee.merge(manager, on='EmpId')
# Out:
#    EmpId    EmpName  location Manager_Name
# 0      1     Sachin    Mumbai        Kapil
# 1      2     Sourav   Kolkata         Ravi
# 2      3     Zaheer    Nagpur      Srinath
# 3      4  Harbhajan  Amritsar     Prasanna

# %%
pd.merge(employee, manager, on='EmpId', how='left')
# Out:
#    EmpId    EmpName   location Manager_Name
# 0      1     Sachin     Mumbai        Kapil
# 1      2     Sourav    Kolkata         Ravi
# 2      3     Zaheer     Nagpur      Srinath
# 3      4  Harbhajan   Amritsar     Prasanna
# 4      7    Rishika  Bangalore          NaN

# %%
pd.merge(employee, manager, on='EmpId', how='right')
# Out:
#    EmpId    EmpName  location Manager_Name
# 0      1     Sachin    Mumbai        Kapil
# 1      2     Sourav   Kolkata         Ravi
# 2      3     Zaheer    Nagpur      Srinath
# 3      4  Harbhajan  Amritsar     Prasanna
# 4      5        NaN       NaN      Padmini
# 5      6        NaN       NaN         Babu

# %%
pd.merge(employee, manager, on='EmpId', how='outer')
# Out:
#    EmpId    EmpName   location Manager_Name
# 0      1     Sachin     Mumbai        Kapil
# 1      2     Sourav    Kolkata         Ravi
# 2      3     Zaheer     Nagpur      Srinath
# 3      4  Harbhajan   Amritsar     Prasanna
# 4      5        NaN        NaN      Padmini
# 5      6        NaN        NaN         Babu
# 6      7    Rishika  Bangalore          NaN

# %%
pd.merge(employee, manager, how='cross')
# Out:
#     EmpId_x    EmpName   location  EmpId_y Manager_Name
# 0         1     Sachin     Mumbai        1        Kapil
# 1         1     Sachin     Mumbai        2         Ravi
# 2         1     Sachin     Mumbai        3      Srinath
# 3         1     Sachin     Mumbai        4     Prasanna
# 4         1     Sachin     Mumbai        5      Padmini
# 5         1     Sachin     Mumbai        6         Babu
# 6         2     Sourav    Kolkata        1        Kapil
# 7         2     Sourav    Kolkata        2         Ravi
# 8         2     Sourav    Kolkata        3      Srinath
# 9         2     Sourav    Kolkata        4     Prasanna
# 10        2     Sourav    Kolkata        5      Padmini
# 11        2     Sourav    Kolkata        6         Babu
# 12        3     Zaheer     Nagpur        1        Kapil
# 13        3     Zaheer     Nagpur        2         Ravi
# 14        3     Zaheer     Nagpur        3      Srinath
# 15        3     Zaheer     Nagpur        4     Prasanna
# 16        3     Zaheer     Nagpur        5      Padmini
# 17        3     Zaheer     Nagpur        6         Babu
# 18        4  Harbhajan   Amritsar        1        Kapil
# 19        4  Harbhajan   Amritsar        2         Ravi
# 20        4  Harbhajan   Amritsar        3      Srinath
# 21        4  Harbhajan   Amritsar        4     Prasanna
# 22        4  Harbhajan   Amritsar        5      Padmini
# 23        4  Harbhajan   Amritsar        6         Babu
# 24        7    Rishika  Bangalore        1        Kapil
# 25        7    Rishika  Bangalore        2         Ravi
# 26        7    Rishika  Bangalore        3      Srinath
# 27        7    Rishika  Bangalore        4     Prasanna
# 28        7    Rishika  Bangalore        5      Padmini
# 29        7    Rishika  Bangalore        6         Babu

# %%
manager = pd.DataFrame({'emp_id': [1,2,3,4,5,6], 'Manager_Name': ['Kapil', 'Ravi', 'Srinath', 'Prasanna','Padmini','Babu']})

manager
# Out:
#    emp_id Manager_Name
# 0       1        Kapil
# 1       2         Ravi
# 2       3      Srinath
# 3       4     Prasanna
# 4       5      Padmini
# 5       6         Babu

# %%
employee
# Out:
#    EmpId    EmpName   location
# 0      1     Sachin     Mumbai
# 1      2     Sourav    Kolkata
# 2      3     Zaheer     Nagpur
# 3      4  Harbhajan   Amritsar
# 4      7    Rishika  Bangalore

# %%
pd.merge(employee, manager, left_on='EmpId', right_on='emp_id')
# Out:
#    EmpId    EmpName  location  emp_id Manager_Name
# 0      1     Sachin    Mumbai       1        Kapil
# 1      2     Sourav   Kolkata       2         Ravi
# 2      3     Zaheer    Nagpur       3      Srinath
# 3      4  Harbhajan  Amritsar       4     Prasanna

# %%
students = pd.DataFrame({'Name': ['Michael', 'Jonty', 'Michael', 'Roger', 'Lionel'], 
                         'Surname': ['Jordan', 'Rhodes', 'Jackson', 'Federer', 'Messi'],
                         'Ages': [15, 17, 12, 9, 10],
                         })

coaches = pd.DataFrame({'Name': ['Michael', 'Rafael', 'Lionel', 'Michael'], 
                         'Surname': ['Jordan', 'Nadal', 'Messi','Jackson'],
                         'Coach Name': ['Rajkumar Rao', 'Pankaj Tripathi', 'Viv Richards', 'Amir Khan'],
                         'Coach Salary': [17000, 25000, 20000, 16000]
                         })

# %%
students
# Out:
#       Name  Surname  Ages
# 0  Michael   Jordan    15
# 1    Jonty   Rhodes    17
# 2  Michael  Jackson    12
# 3    Roger  Federer     9
# 4   Lionel    Messi    10

# %%
coaches
# Out:
#       Name  Surname       Coach Name  Coach Salary
# 0  Michael   Jordan     Rajkumar Rao         17000
# 1   Rafael    Nadal  Pankaj Tripathi         25000
# 2   Lionel    Messi     Viv Richards         20000
# 3  Michael  Jackson        Amir Khan         16000

# %%
pd.merge(students, coaches, on=['Name','Surname'])   # joining on multiple keys
# Out:
#       Name  Surname  Ages    Coach Name  Coach Salary
# 0  Michael   Jordan    15  Rajkumar Rao         17000
# 1  Michael  Jackson    12     Amir Khan         16000
# 2   Lionel    Messi    10  Viv Richards         20000

# %% [markdown]
# #### Join

# %% [markdown]
# `join()`: primarily joins the DataFrames based on their indexes. By default, it performs a left join, keeping all rows from the left DataFrame and matching rows from the right DataFrame based on index values.

# %%
dfA = pd.DataFrame({'keyA': ['a', 'b', 'c', 'd', 'e', 'f'], 'values_A': [10, 20, 30, 40 ,50, 60]})

dfB = pd.DataFrame({'keyB': ['a', 'b', 'c'], 'values_B': [111, 222, 333]})

# %%
dfA
# Out:
#   keyA  values_A
# 0    a        10
# 1    b        20
# 2    c        30
# 3    d        40
# 4    e        50
# 5    f        60

# %%
dfB
# Out:
#   keyB  values_B
# 0    a       111
# 1    b       222
# 2    c       333

# %%
dfA.join(dfB)
# Out:
#   keyA  values_A keyB  values_B
# 0    a        10    a     111.0
# 1    b        20    b     222.0
# 2    c        30    c     333.0
# 3    d        40  NaN       NaN
# 4    e        50  NaN       NaN
# 5    f        60  NaN       NaN

# %%
dfA.join(dfB, how='right')
# Out:
#   keyA  values_A keyB  values_B
# 0    a        10    a       111
# 1    b        20    b       222
# 2    c        30    c       333

# %%
dfA.join(dfB, how='outer')
# Out:
#   keyA  values_A keyB  values_B
# 0    a        10    a     111.0
# 1    b        20    b     222.0
# 2    c        30    c     333.0
# 3    d        40  NaN       NaN
# 4    e        50  NaN       NaN
# 5    f        60  NaN       NaN

# %%
dfA.join(dfB, how='inner')
# Out:
#   keyA  values_A keyB  values_B
# 0    a        10    a       111
# 1    b        20    b       222
# 2    c        30    c       333

# %%
dfA = pd.DataFrame({'key': ['a', 'b', 'c', 'd', 'e', 'f'], 'values_A': [10, 20, 30, 40 ,50, 60]})

dfB = pd.DataFrame({'key': ['a', 'b', 'c'], 'values_B': [111, 222, 333]})

# %%
dfA
# Out:
#   key  values_A
# 0   a        10
# 1   b        20
# 2   c        30
# 3   d        40
# 4   e        50
# 5   f        60

# %%
dfB
# Out:
#   key  values_B
# 0   a       111
# 1   b       222
# 2   c       333

# %%
dfA.join(dfB,  lsuffix='_A', rsuffix='_B')
# Out:
#   key_A  values_A key_B  values_B
# 0     a        10     a     111.0
# 1     b        20     b     222.0
# 2     c        30     c     333.0
# 3     d        40   NaN       NaN
# 4     e        50   NaN       NaN
# 5     f        60   NaN       NaN

# %%
dfA.set_index('key')
# Out:
#      values_A
# key
# a          10
# b          20
# c          30
# d          40
# e          50
# f          60

# %%
dfA.set_index('key').join(dfB.set_index('key'))
# Out:
#      values_A  values_B
# key
# a          10     111.0
# b          20     222.0
# c          30     333.0
# d          40       NaN
# e          50       NaN
# f          60       NaN

# %% [markdown]
# #### Concat
#
# With concatenation, your datasets are just stitched together along an axis — either the row axis or column axis.
#
# Concatenation along rows           |  Concatenation along columns
# :-------------------------:|:-------------------------:
# ![](https://files.realpython.com/media/concat_axis0.2ec65b5f72bc.png)  |  ![](https://files.realpython.com/media/concat_col.a8eec2b4e84f.png)

# %%
df1 = pd.DataFrame(np.array([[1, 6, 8],[5, 4, 2],[3, 9, 4],[7, 2, 0]]), columns=['a', 'b', 'c'])

df2 = pd.DataFrame(np.array([[3, 4, 8, 2],[0, 1, 4, 5],[7, 5, 2, 1]]), columns=['b','c','d','e'])

# %%
df1
# Out:
#    a  b  c
# 0  1  6  8
# 1  5  4  2
# 2  3  9  4
# 3  7  2  0

# %%
df2
# Out:
#    b  c  d  e
# 0  3  4  8  2
# 1  0  1  4  5
# 2  7  5  2  1

# %%
df = pd.concat([df1,df2],axis=0)  # Concatenation along rows

# %%
df
# Out:
#      a  b  c    d    e
# 0  1.0  6  8  NaN  NaN
# 1  5.0  4  2  NaN  NaN
# 2  3.0  9  4  NaN  NaN
# 3  7.0  2  0  NaN  NaN
# 0  NaN  3  4  8.0  2.0
# 1  NaN  0  1  4.0  5.0
# 2  NaN  7  5  2.0  1.0

# %%
pd.concat([df1,df2],axis=1)  # Concatenation along columns
# Out:
#    a  b  c    b    c    d    e
# 0  1  6  8  3.0  4.0  8.0  2.0
# 1  5  4  2  0.0  1.0  4.0  5.0
# 2  3  9  4  7.0  5.0  2.0  1.0
# 3  7  2  0  NaN  NaN  NaN  NaN

# %%
pd.concat([df1,df2],axis=1)['b']  # Creates problems
# Out:
#    b    b
# 0  6  3.0
# 1  4  0.0
# 2  9  7.0
# 3  2  NaN

# %%
pd.concat([df1,df2])  # By default the axis is 0
# Out:
#      a  b  c    d    e
# 0  1.0  6  8  NaN  NaN
# 1  5.0  4  2  NaN  NaN
# 2  3.0  9  4  NaN  NaN
# 3  7.0  2  0  NaN  NaN
# 0  NaN  3  4  8.0  2.0
# 1  NaN  0  1  4.0  5.0
# 2  NaN  7  5  2.0  1.0

# %% [markdown]
# ### Missing value and Duplicate value treatment

# %%
covid_data
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           179267
# 1                      Albania             Europe           275574
# 2                      Algeria             Africa           265816
# 3                      Andorra             Europe            42156
# 4                       Angola             Africa            99194
# ..                         ...                ...              ...
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          7690.0         162202.0        9375.0               1124.0
# 1          3497.0         271826.0         251.0                  2.0
# 2          6875.0         178371.0       80570.0                  6.0
# 3           153.0          41021.0         982.0                 14.0
# 4          1900.0          97149.0         145.0                  NaN
# ..            ...              ...           ...                  ...
# 221           7.0            438.0           9.0                  NaN
# 222           1.0              9.0           0.0                  NaN
# 223        2149.0           9009.0         661.0                 23.0
# 224        3983.0         315997.0         611.0                  NaN
# 225        5482.0         242417.0        1307.0                 12.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                             4420                           190.0
# 1                            95954                          1218.0
# 2                             5865                           152.0
# 3                           543983                          1974.0
# 4                             2853                            55.0
# ..                             ...                             ...
# 221                          41755                           644.0
# 222                             16                             2.0
# 223                            381                            69.0
# 224                          16575                           206.0
# 225                          16324                           359.0
#
#      total_tests  total_tests_per_1m_population  population
# 0       951337.0                        23455.0    40560636
# 1      1817530.0                       632857.0     2871945
# 2       230861.0                         5093.0    45325517
# 3       249838.0                      3223924.0       77495
# 4      1499795.0                        43136.0    34769277
# ..           ...                            ...         ...
# 221      20508.0                      1886140.0       10873
# 222          NaN                            NaN      624681
# 223     265253.0                         8543.0    31049015
# 224    3452554.0                       178497.0    19342381
# 225    2287793.0                       149863.0    15265849
#
# [226 rows x 12 columns]

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         226 non-null    object
#  1   continent                       226 non-null    object
#  2   total_confirmed                 226 non-null    int64
#  3   total_deaths                    218 non-null    float64
#  4   total_recovered                 204 non-null    float64
#  5   active_cases                    204 non-null    float64
#  6   serious_or_critical             145 non-null    float64
#  7   total_cases_per_1m_population   226 non-null    int64
#  8   total_deaths_per_1m_population  218 non-null    float64
#  9   total_tests                     212 non-null    float64
#  10  total_tests_per_1m_population   212 non-null    float64
#  11  population                      226 non-null    int64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 21.3+ KB

# %%
covid_data.isnull().sum()  # How many null values are there in each column
# Out:
# country                            0
# continent                          0
# total_confirmed                    0
# total_deaths                       8
# total_recovered                   22
# active_cases                      22
# serious_or_critical               81
# total_cases_per_1m_population      0
# total_deaths_per_1m_population     8
# total_tests                       14
# total_tests_per_1m_population     14
# population                         0
# dtype: int64

# %%
covid_data.dropna()  # Removes rows containig missing data (NaN)
# Out:
#          country      continent  total_confirmed  total_deaths  \
# 0    Afghanistan           Asia           179267        7690.0
# 1        Albania         Europe           275574        3497.0
# 2        Algeria         Africa           265816        6875.0
# 3        Andorra         Europe            42156         153.0
# 5       Anguilla  North America             2984           9.0
# ..           ...            ...              ...           ...
# 217   Uzbekistan           Asia           238802        1637.0
# 219    Venezuela  South America           522921        5711.0
# 220     Viet Nam           Asia         10696630       43065.0
# 223        Yemen           Asia            11819        2149.0
# 225     Zimbabwe         Africa           249206        5482.0
#
#      total_recovered  active_cases  serious_or_critical  \
# 0           162202.0        9375.0               1124.0
# 1           271826.0         251.0                  2.0
# 2           178371.0       80570.0                  6.0
# 3            41021.0         982.0                 14.0
# 5             2916.0          59.0                  4.0
# ..               ...           ...                  ...
# 217         236974.0         191.0                 23.0
# 219         516170.0        1040.0                230.0
# 220        9355040.0     1298525.0                340.0
# 223           9009.0         661.0                 23.0
# 225         242417.0        1307.0                 12.0
#
#      total_cases_per_1m_population  total_deaths_per_1m_population  \
# 0                             4420                           190.0
# 1                            95954                          1218.0
# 2                             5865                           152.0
# 3                           543983                          1974.0
# 5                           195646                           590.0
# ..                             ...                             ...
# 217                           6947                            48.0
# 219                          18487                           202.0
# 220                         108080                           435.0
# 223                            381                            69.0
# 225                          16324                           359.0
#
#      total_tests  total_tests_per_1m_population  population
# 0       951337.0                        23455.0    40560636
# 1      1817530.0                       632857.0     2871945
# 2       230861.0                         5093.0    45325517
# 3       249838.0                      3223924.0       77495
# 5        51382.0                      3368870.0       15252
# ..           ...                            ...         ...
# 217    1377915.0                        40088.0    34372515
# 219    3359014.0                       118752.0    28285909
# 220   85811485.0                       867048.0    98969721
# 223     265253.0                         8543.0    31049015
# 225    2287793.0                       149863.0    15265849
#
# [131 rows x 12 columns]

# %%
covid_data.dropna(axis=1) # Removes columns containing missing data
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           179267
# 1                      Albania             Europe           275574
# 2                      Algeria             Africa           265816
# 3                      Andorra             Europe            42156
# 4                       Angola             Africa            99194
# ..                         ...                ...              ...
# 221  Wallis And Futuna Islands  Australia/Oceania              454
# 222             Western Sahara             Africa               10
# 223                      Yemen               Asia            11819
# 224                     Zambia             Africa           320591
# 225                   Zimbabwe             Africa           249206
#
#      total_cases_per_1m_population  population
# 0                             4420    40560636
# 1                            95954     2871945
# 2                             5865    45325517
# 3                           543983       77495
# 4                             2853    34769277
# ..                             ...         ...
# 221                          41755       10873
# 222                             16      624681
# 223                            381    31049015
# 224                          16575    19342381
# 225                          16324    15265849
#
# [226 rows x 5 columns]

# %%
covid_data_filled = covid_data.fillna(value=0)   # fills the missing values with 0

covid_data_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         226 non-null    object
#  1   continent                       226 non-null    object
#  2   total_confirmed                 226 non-null    int64
#  3   total_deaths                    226 non-null    float64
#  4   total_recovered                 226 non-null    float64
#  5   active_cases                    226 non-null    float64
#  6   serious_or_critical             226 non-null    float64
#  7   total_cases_per_1m_population   226 non-null    int64
#  8   total_deaths_per_1m_population  226 non-null    float64
#  9   total_tests                     226 non-null    float64
#  10  total_tests_per_1m_population   226 non-null    float64
#  11  population                      226 non-null    int64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 21.3+ KB

# %%
covid_data_filled.isnull().sum()
# Out:
# country                           0
# continent                         0
# total_confirmed                   0
# total_deaths                      0
# total_recovered                   0
# active_cases                      0
# serious_or_critical               0
# total_cases_per_1m_population     0
# total_deaths_per_1m_population    0
# total_tests                       0
# total_tests_per_1m_population     0
# population                        0
# dtype: int64

# %%
employee = pd.DataFrame({'Name': ['Susan', 'Maria', 'Olivia', 'Dipika', 'Rashmika'], 
                         'Role': ['Engineer','Manager',np.nan,'Scientist',np.nan],
                         'Salary': [40000, np.nan, 25000, np.nan, 20000]})

employee
# Out:
#        Name       Role   Salary
# 0     Susan   Engineer  40000.0
# 1     Maria    Manager      NaN
# 2    Olivia        NaN  25000.0
# 3    Dipika  Scientist      NaN
# 4  Rashmika        NaN  20000.0

# %%
employee_filled = employee.fillna({'Role':'Engineer', 'Salary': 15000})

employee_filled
# Out:
#        Name       Role   Salary
# 0     Susan   Engineer  40000.0
# 1     Maria    Manager  15000.0
# 2    Olivia   Engineer  25000.0
# 3    Dipika  Scientist  15000.0
# 4  Rashmika   Engineer  20000.0

# %%
df_dup = pd.concat([df1, df1]).reset_index(drop=True)

df_dup
# Out:
#    a  b  c
# 0  1  6  8
# 1  5  4  2
# 2  3  9  4
# 3  7  2  0
# 4  1  6  8
# 5  5  4  2
# 6  3  9  4
# 7  7  2  0

# %%
df_dup.drop_duplicates()   #removes duplicates from the dataset
# Out:
#    a  b  c
# 0  1  6  8
# 1  5  4  2
# 2  3  9  4
# 3  7  2  0

# %%
students
# Out:
#       Name  Surname  Ages
# 0  Michael   Jordan    15
# 1    Jonty   Rhodes    17
# 2  Michael  Jackson    12
# 3    Roger  Federer     9
# 4   Lionel    Messi    10

# %%
students.drop_duplicates()
# Out:
#       Name  Surname  Ages
# 0  Michael   Jordan    15
# 1    Jonty   Rhodes    17
# 2  Michael  Jackson    12
# 3    Roger  Federer     9
# 4   Lionel    Messi    10

# %%
students.drop_duplicates(['Name'])
# Out:
#       Name  Surname  Ages
# 0  Michael   Jordan    15
# 1    Jonty   Rhodes    17
# 3    Roger  Federer     9
# 4   Lionel    Messi    10

# %% [markdown]
# ### inplace operations
#
# The `inplace` parameter in pandas allows certain operations to modify a DataFrame directly, without creating a new copy. Some common pandas operations that support the inplace parameter are:
# - dropna(): Removes rows or columns with missing values.
# - fillna(): Fills missing values with a specified value.
# - replace(): Replaces values in a DataFrame.
# - drop(): Removes rows or columns by label.
# - drop_duplicates(): Removes duplicate rows.
# - set_index(): Sets the DataFrame index.
# - reset_index(): Resets the DataFrame index.
# - sort_values(): Sorts the DataFrame by column values.
# - sort_index(): Sorts the DataFrame by index.
# - rename(): Renames columns or index labels.
# - update(): Modifies in place using non-NA values from another DataFrame.

# %%
employee
# Out:
#        Name       Role   Salary
# 0     Susan   Engineer  40000.0
# 1     Maria    Manager      NaN
# 2    Olivia        NaN  25000.0
# 3    Dipika  Scientist      NaN
# 4  Rashmika        NaN  20000.0

# %%
employee.fillna({'Role':'Engineer', 'Salary': 15000}, inplace=True)

# %%
employee
# Out:
#        Name       Role   Salary
# 0     Susan   Engineer  40000.0
# 1     Maria    Manager  15000.0
# 2    Olivia   Engineer  25000.0
# 3    Dipika  Scientist  15000.0
# 4  Rashmika   Engineer  20000.0
