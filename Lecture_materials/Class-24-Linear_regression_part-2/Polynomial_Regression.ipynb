# %% [markdown]
# # Polynomial Regression
#
# Here we shall discuss how polynomial regression does better job in identifying true relationship among variables.

# %% [markdown]
# ## Data
#
# The data is a sample of height, weight, age and gender of peoples of Kung-San tribe in the Kalahari desert of Africa.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./height_weight_kung_san_people.csv", sep=',')

# %%
data.head()
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041914  41.0     1
# 4  145.415  41.276872  51.0     0

# %%
data.shape
# Out:
# (544, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  544 non-null    float64
#  1   weight  544 non-null    float64
#  2   age     544 non-null    float64
#  3   male    544 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 17.1 KB

# %% [markdown]
# We shall try to find a relationship between the weight and height of Kung San people using this data.
#
# Here *weight* is our target variable.

# %% [markdown]
# ## Plotting

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(data=data, x='height', y='weight')
plt.grid()
#plt.legend()
plt.title("Weight vs Height", fontsize=16)
plt.xlabel("Height", fontsize=14)
plt.ylabel("Weight", fontsize=14)
plt.show()

# %% [markdown]
# ## Polynomial Regression of order 1 (i.e. simple linear regression)
#
# i.e. we are trying fit the equation:
#
# $$ y = \hat{\theta}_0 + \hat{\theta}_1 x $$
#
# Where $x$ is *height* and $y$ is *weight*

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Fit the model

# %%
first_order_model = LinearRegression()

# %%
first_order_model.fit(X=data['height'].values.reshape(-1,1), y=data['weight'].values)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model parameters

# %%
first_order_model.intercept_
# Out:
# np.float64(-33.75613690832986)

# %%
first_order_model.coef_
# Out:
# array([0.50169934])

# %% [markdown]
# The model looks like:
#
# $$ \hat{weight} = -33.756 + 0.502 \times height$$

# %% [markdown]
# ### The model output

# %%
x_min = data['height'].min()
x_max = data['height'].max()
x_values = np.linspace(x_min, x_max, 100)
y_values_first_order = first_order_model.predict(x_values.reshape(-1,1))

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=data, x='height', y='weight')
plt.plot(x_values, y_values_first_order, color='r', label='Regression Line')
plt.legend()
plt.grid()
plt.title("Weight vs Height", fontsize=16)
plt.xlabel("Height", fontsize=14)
plt.ylabel("Weight", fontsize=14)
plt.show()

# %% [markdown]
# As we can see from the above graph that the "first order regression line" doesn't fit well to the data.
# We can use higher order polynomials to describe the relationship.

# %% [markdown]
# ### Calculate coefficient of determination

# %%
from sklearn.metrics import r2_score

# %%
y_p_1 = first_order_model.predict(data['height'].values.reshape(-1,1))

# %%
error = y_p_1 - data['weight'].values
error
# Out:
# array([-5.44134364e+00, -1.54546136e-01,  2.87352697e+00, -8.10901902e+00,
#        -2.07839993e+00, -1.45553237e+01,  2.86647104e+00, -4.49407353e+00,
#         5.60290338e+00, -5.41331550e+00, -6.23654083e+00,  8.45510777e-01,
#         2.84767849e+00, -6.25140641e+00,  7.89780170e+00, -4.44007232e-01,
#         2.92567106e+00,  1.02495108e-01,  7.79319217e+00,  5.18003612e+00,
#        -9.18697231e-01, -1.82498697e+00,  1.89161990e+00,  7.64721111e+00,
#         5.05034660e+00,  4.19907192e+00,  2.88808596e+00,  4.68898481e+00,
#         7.72802605e+00,  6.64292064e+00,  5.72791222e+00,  1.59799384e-01,
#        -7.62989989e+00,  2.01066265e+00,  1.01843015e+00, -3.75081811e+00,
#        -9.14659244e-01,  2.34553326e+00, -6.92757562e+00, -1.03793555e+00,
#        -7.02891564e+00, -1.43180385e+00, -4.29703821e+00,  1.03189931e+00,
#        -9.42233162e+00,  1.00768010e+01,  6.99940617e+00,  7.55542803e+00,
#         2.03747518e+00,  2.41005667e+00, -3.12585165e-01, -2.55684428e+00,
#         6.01012062e-01,  7.94912699e+00,  6.25449475e+00,  2.54776618e+00,
#        -9.20541392e+00, -4.01713407e+00, -6.93822240e+00, -4.98628231e+00,
#        -1.00219047e+01,  2.85800393e+00, -5.63979014e+00, -5.05682997e+00,
#        -3.96858083e+00, -6.44422293e+00, -3.21237993e+00,  6.21703543e+00,
#        -7.49629815e+00,  1.36676991e+00,  6.68332811e+00,  5.60604711e+00,
#        -4.96754791e+00,  5.87864256e-01,  9.92017315e+00,  2.85659274e+00,
#        -1.56399440e+00, -8.08121603e-01, -8.15648242e+00,  3.49689462e+00,
#        -1.42777262e+00,  7.79145963e+00, -3.22475925e+00,  3.79264991e+00,
#        -2.78213539e+00,  1.09533288e+00,  5.80622614e+00, -4.48178820e+00,
#         1.35721296e+00, -1.54899503e+00, -6.96330360e-01, -3.38921151e+00,
#        -2.69426452e+00,  3.76395731e-01,  6.99408277e+00,  3.06036263e+00,
#        -3.29069385e+00,  5.08587781e+00,  5.06240457e+00, -8.95559181e+00,
#         6.02173266e+00, -8.55305407e+00, -7.04476124e-01,  4.91847620e-01,
#         5.20883276e+00, -7.03738276e+00,  3.22936980e+00,  4.03271275e+00,
#         8.33118996e+00,  4.87210383e+00,  5.81437191e+00,  1.84556769e+00,
#         1.59606693e+00,  1.04282845e+01,  7.23184691e+00, -1.91092973e+00,
#         4.02424563e+00,  2.01066265e+00,  1.18820580e+00, -2.03420723e-01,
#        -8.01191255e+00, -2.21937895e+00, -6.30279678e+00, -6.23461272e+00,
#        -9.82326380e-01, -6.56185449e+00,  1.57041402e+00,  5.75106411e+00,
#        -8.21850481e+00, -1.04575996e+00,  5.47135554e+00,  1.36999186e+00,
#        -4.97992723e+00, -2.75378589e+00, -3.32577793e+00, -9.82647732e-01,
#         3.56706278e+00, -8.06296680e+00,  7.97361460e+00, -7.81911079e+00,
#         4.10906897e-01, -2.68752994e+00,  3.41043493e+00,  2.97986904e+00,
#         9.23478311e+00,  3.27150981e+00, -2.92888493e+00,  7.62309517e+00,
#         6.48661414e+00,  6.86060562e-01, -4.19537683e+00,  5.59681151e+00,
#         5.34030636e+00, -5.16631576e+00,  4.92533776e+00,  1.82286293e+00,
#         1.40031702e+00, -4.68424311e+00, -2.83742320e+00, -1.20102819e+01,
#        -7.24647605e+00, -8.52220355e+00, -1.13080846e+00,  6.63618606e+00,
#        -3.96825948e+00, -5.71951525e+00, -7.05162040e+00,  5.71251376e-01,
#        -3.75816423e-01, -7.18695467e+00,  5.41497789e+00,  6.99725289e-01,
#         5.02494405e-01,  1.08163890e+01, -6.72553826e+00, -1.12448454e+01,
#         3.98698188e+00, -2.63897670e+00, -9.47261739e+00,  2.19672983e+00,
#        -3.97140320e+00, -6.71424877e+00, -8.90453755e+00,  7.23645661e-01,
#         5.76235360e+00,  5.71912376e+00,  9.38858858e+00,  5.86933837e+00,
#         4.61945935e+00,  7.08913536e+00, -7.09799517e-01, -3.09365854e+00,
#        -3.06171938e-01,  2.41961362e+00, -6.90685616e-01,  4.40927623e+00,
#        -2.22438099e+00, -6.79288405e+00, -1.11948810e+01,  5.24597072e+00,
#         3.14842907e+00, -3.39985829e+00, -4.11228603e-01,  2.10071319e+00,
#         7.11909041e-01, -5.59405928e+00,  2.75980762e+00,  6.33434564e+00,
#         2.75698405e-01,  1.27216446e+00,  7.17168283e+00, -3.11809583e+00,
#         9.68022934e+00,  4.62664106e+00, -4.92714044e+00,  2.38170717e+00,
#         2.82561644e+00, -3.93268110e+00, -5.79218443e+00, -4.26272262e+00,
#         2.49639057e+00,  3.90007507e+00,  5.30452804e+00, -1.24029425e+00,
#        -3.08994310e-01, -7.38149017e-01,  7.23967132e+00, -1.39817176e+00,
#        -2.31193051e+00, -1.70837665e-01, -1.01741046e+00,  4.01488425e+00,
#         3.18505012e+00,  1.05710508e+00, -3.62549587e-01,  5.22198056e+00,
#        -6.54838533e+00, -5.85202715e+00, -9.85683595e-01,  2.57341909e+00,
#         6.65215624e+00, -8.72840587e-01,  3.09140872e+00,  4.59546919e+00,
#         7.65221315e+00,  5.88030651e+00, -1.46709025e+00,  8.34863992e-01,
#         3.77603028e+00,  3.74671673e+00,  1.82286293e+00,  5.26610347e-01,
#         1.68079408e+00, -1.76546560e+00,  1.53936793e+00,  5.06349420e-02,
#         2.47881364e+00, -1.87647317e-02,  5.35308128e+00, -4.46269933e+00,
#         2.73145812e+00,  9.51852847e-01,  1.08468610e+00, -8.94581289e-01,
#        -1.66925459e-01,  3.90430862e+00, -5.24680935e+00, -3.27081147e+00,
#        -7.48141781e+00,  1.26684107e+00,  3.70489807e+00, -6.51503379e+00,
#         8.47075779e+00,  1.78354530e+00,  1.81473729e+00, -1.22541391e+00,
#         1.90367788e+00,  1.26401870e+00, -2.97352596e+00,  5.55075929e+00,
#         3.50786276e+00,  4.76983886e+00,  4.20704331e+00, -1.75479281e+00,
#        -4.42781757e+00,  9.44464488e+00,  2.82856459e+00, -5.73696761e-01,
#        -1.90439072e+00,  6.68018438e+00,  7.78133652e+00,  5.32569583e+00,
#        -6.86857899e+00,  2.41852379e+00, -1.15383457e+00, -4.16029275e+00,
#        -2.27825762e+00,  3.40119933e+00,  1.33878088e+00,  4.65531191e+00,
#         6.79521554e-01, -8.04083616e-01,  4.57808783e+00,  5.79993870e+00,
#        -6.61996467e+00, -2.09751383e+00,  6.50980346e+00,  1.87943615e+00,
#        -3.96325744e+00, -7.83931453e+00, -1.71267880e+00,  4.48194541e+00,
#        -5.43884262e+00, -3.40166182e-01,  4.31511791e+00, -1.78983430e-01,
#        -1.30365086e+01, -1.58779694e-01, -3.40723557e+00,  3.04862601e+00,
#        -2.83177846e+00, -8.07534612e+00, -3.96575846e+00, -2.51973839e+00,
#        -3.15016197e+00, -9.74462902e+00,  6.51172054e-01,  3.68142483e+00,
#         4.32521818e-01,  2.00642909e+00,  1.65149175e-02, -9.21183558e+00,
#        -4.53787628e+00, -3.00652975e-01, -3.48079902e+00, -1.53456302e-01,
#        -1.39737145e-01,  7.94296640e+00, -2.25926950e+00,  2.42211464e+00,
#         2.86666541e-01, -4.80181145e-01, -2.23252675e+00,  7.78504640e+00,
#         2.61511197e+00, -6.91006967e-01, -1.73288254e+00, -2.07993690e+00,
#        -1.07529868e-01, -1.66162455e+00, -6.18016438e-01, -2.87000626e+00,
#        -2.31898644e+00, -8.08121603e-01, -9.09730863e+00,  6.14045405e+00,
#        -8.41990066e-01, -7.28592066e-01, -4.48791186e+00,  9.33112110e+00,
#        -5.61624712e+00, -1.70272396e+00, -7.18752759e+00, -3.42692239e+00,
#        -6.50855077e+00, -5.73048339e+00, -1.97597007e+00, -1.71389442e+00,
#        -1.21848376e+00, -5.12757104e+00, -9.17286045e-01, -9.94705703e-01,
#         8.97258168e+00,  5.93918518e+00, -5.45795653e+00,  8.03345732e+00,
#        -4.66865564e+00, -4.78878822e+00,  1.77376318e-01, -9.26602512e+00,
#        -7.63438501e+00,  7.20426589e+00, -1.91535886e+00, -1.86769989e+00,
#        -9.29665368e-01, -2.45791157e+00, -1.23355967e+00, -5.21595883e+00,
#        -1.64533302e+00,  6.32716393e+00,  5.44441722e+00, -2.61825605e+00,
#         7.29290405e-01,  7.89812305e+00,  4.53723322e+00, -4.40989289e-01,
#        -5.37964260e+00,  3.86595384e-01,  9.76777886e+00, -5.55082944e+00,
#        -4.74023499e+00, -8.19322924e+00,  5.66946424e-01,  4.16868972e+00,
#         1.61376965e+00, -2.19353047e+00, -6.02660927e+00,  5.31299516e+00,
#        -7.49263751e+00, -2.36471730e+00, -2.91041373e+00,  2.47864626e-02,
#         3.22827996e+00, -4.11456189e+00, -1.48055941e+00, -7.37250493e+00,
#        -1.33740072e+00,  1.71728935e+00,  3.47386851e+00,  7.59942636e+00,
#         9.71531342e+00,  5.32190940e+00, -7.99850058e-01, -2.78745878e+00,
#         2.31718376e+00, -7.68803967e-01, -1.24146400e+00, -1.03120097e+00,
#         6.04638656e-01, -3.96236992e+00, -5.11853101e+00,  4.21551042e+00,
#         5.08091488e+00, -1.66835912e+00,  4.79814925e+00,  3.18404575e-01,
#        -6.89507079e+00, -3.08470518e+00, -4.24534125e+00,  2.11107099e+00,
#        -8.24178248e+00, -6.41042546e-01,  4.60393631e+00,  3.24315572e+00,
#        -8.80537719e+00,  1.78165124e+00, -9.51475860e-01,  3.18646131e+00,
#         3.83531191e+00,  3.17395620e+00,  8.72692214e-01,  3.38349662e+00,
#        -4.03149749e+00,  1.94562111e-01,  8.13467832e+00, -8.44164016e+00,
#        -9.41758114e+00, -6.95765765e+00,  7.98426138e+00, -7.67845312e+00,
#        -4.50048675e+00, -3.60048566e-01, -9.79285921e+00,  5.32755415e+00,
#        -7.45286768e+00,  3.94625306e+00, -1.05689425e+01, -9.40943537e+00,
#        -1.95435514e+00,  5.42748299e+00,  8.60326969e+00, -2.79226525e+00,
#        -4.42596046e-01, -4.05895272e+00,  7.22620217e+00, -8.66446107e-04,
#        -4.06036391e+00, -6.97420194e-01, -1.40174516e+01,  1.19070562e-01,
#         4.95955397e-01,  1.73640325e+00, -3.40268067e+00, -1.17916612e+00,
#         3.52601140e-01, -1.11016867e+01,  7.16135740e+00, -7.50011417e-01,
#        -2.74564012e+00,  7.10433705e+00, -2.12477350e+00,  1.20481748e-01,
#         4.30511383e+00,  7.81807659e+00,  4.95227607e+00, -5.59842240e+00,
#         6.33466699e+00,  1.66059035e+00,  5.29073753e+00,  5.75709027e+00,
#         3.86796603e+00, -2.01419787e+00, -1.54931638e+00,  6.82116340e+00,
#        -2.49138889e+00,  7.07002145e+00,  6.30772748e-01,  3.96774220e+00,
#         7.72693621e+00, -2.96178934e+00,  2.19652750e+00,  9.40770248e+00,
#         5.05091614e-02,  3.72215365e+00, -4.23482145e-01,  4.90090046e+00,
#        -8.85219909e-01, -1.09293402e+01,  1.76225173e+00, -1.05622079e+01,
#         2.58143907e+00,  4.19280567e+00, -3.48450890e+00, -1.34663752e-01,
#         5.87542905e-01,  7.85098100e+00,  6.40939006e+00,  2.87166865e+00,
#        -1.03793555e+00,  1.11246149e-01,  8.04942750e+00, -4.51636074e-01,
#         3.56424040e+00,  1.87956193e+00,  7.68286690e-01,  6.38668530e+00,
#        -6.89729801e+00,  3.67795976e+00, -3.23097691e+00,  8.07072107e+00,
#        -4.36297281e+00, -9.44818010e+00, -6.12653812e+00, -6.64299078e+00])

# %%
# error vs predictor
plt.figure(figsize=(10,8))
plt.scatter(data['height'].values, error)
plt.xlabel("Height")
plt.ylabel("error")
plt.show()

# %%
r2_1 = r2_score(y_true=data['weight'].values, y_pred=y_p_1)

print(f"Coefficient of determination for first order polynomial: {r2_1}")
# Out:
# Coefficient of determination for first order polynomial: 0.8851464200503394

# %% [markdown]
# ### Calculate adjusted R-squared

# %%
def adjusted_R_squared(m, k, r2):
    return (1 - ((m-1)*(1-r2)/(m-k-1)))

# %%
m = len(data)
k = 1

# %%
adjusted_R_squared(m, k, r2_1)
# Out:
# 0.8849345130762625

# %% [markdown]
# ## Second order Polynomial Regression
#
#
# i.e. we are trying fit the equation:
#
# $$ y = \hat{\theta}_0 + \hat{\theta}_1 x + \hat{\theta}_2 x^2 $$
#
# Where $x$ is *height* and $y$ is *weight*.
#
# So, in order to achieve that:
#
# - $x_1 = x$
#
# - $x_2 = x^2$
#
# Then the equation becomes
#
# $$ y = \hat{\theta}_0 + \hat{\theta}_1 x_1 + \hat{\theta}_2 x_2 $$
#
# Which can now be solved using Multiple Linear Regression

# %% [markdown]
# ### Prepare the data

# %%
x1 = data['height'].values
x2 = np.square(x1)

# %% [markdown]
# $$ X = [x1, x2] $$

# %%
X = np.hstack((x1.reshape(-1,1), x2.reshape(-1,1)))

# %%
X[:5]
# Out:
# array([[  151.765   , 23032.615225],
#        [  139.7     , 19516.09    ],
#        [  136.525   , 18639.075625],
#        [  156.845   , 24600.354025],
#        [  145.415   , 21145.522225]])

# %%
pd.DataFrame(X, columns=['height', 'height_square'])
# Out:
#       height  height_square
# 0    151.765   23032.615225
# 1    139.700   19516.090000
# 2    136.525   18639.075625
# 3    156.845   24600.354025
# 4    145.415   21145.522225
# ..       ...            ...
# 539  145.415   21145.522225
# 540  162.560   26425.753600
# 541  156.210   24401.564100
# 542   71.120    5058.054400
# 543  158.750   25201.562500
#
# [544 rows x 2 columns]

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X=X)
# Out:
# StandardScaler()

# %%
X_std = scaler.transform(X)

# %%
X_std[:,0].min() , X_std[:,0].max()
# Out:
# (np.float64(-3.05647439422663), np.float64(1.4797224464253014))

# %%
X_std[:,1].min() , X_std[:,1].max()
# Out:
# (np.float64(-2.5288189559873486), np.float64(1.8169717368547482))

# %%
X_std[:10]
# Out:
# array([[ 0.48958811,  0.47035907],
#        [ 0.05208689, -0.05384791],
#        [-0.06304501, -0.18458408],
#        [ 0.67379915,  0.70406126],
#        [ 0.25932431,  0.18905089],
#        [ 0.92708933,  1.03796446],
#        [ 0.39748259,  0.35639319],
#        [ 1.11130037,  1.28993965],
#        [ 0.35142983,  0.30013156],
#        [ 0.97314209,  1.10023695]])

# %% [markdown]
# ### fit the model

# %%
second_order_model = LinearRegression()

# %%
second_order_model.fit(X_std, y=data['weight'].values)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model parameters

# %%
second_order_model.intercept_
# Out:
# np.float64(35.610617592463214)

# %%
second_order_model.coef_
# Out:
# array([-13.04264336,  27.05203396])

# %% [markdown]
# The model looks like:
#
# $$\hat{weight} = 35.611 + (-13.043) \times height\_std + (27.052) \times height^{2}\_std$$

# %% [markdown]
# ### Model output

# %%
x_min = data['height'].min()
x_max = data['height'].max()
in_between_values = np.linspace(x_min, x_max, 100)

# %%
x_values = np.hstack((in_between_values.reshape(-1,1), np.square(in_between_values).reshape(-1,1)))

# %%
x_values_std = scaler.transform(x_values)

# %%
y_values_second_order = second_order_model.predict(x_values_std)

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(data=data, x='height', y='weight')
plt.plot(in_between_values, y_values_first_order, 'g--', label='First order Polynomial')
plt.plot(in_between_values, y_values_second_order, color='r', label='Second order Polynomial')
plt.legend()
plt.grid()
plt.title("Weight vs Height", fontsize=16)
plt.xlabel("Height", fontsize=14)
plt.ylabel("Weight", fontsize=14)
plt.show()

# %% [markdown]
# ### Calculate coefficient of determination

# %%
y_p_2 = second_order_model.predict(X_std)

# %%
r2_2 = r2_score(y_true=data['weight'].values, y_pred=y_p_2)

print(f"Coefficient of determination for second order polynomial: {r2_2}")
# Out:
# Coefficient of determination for second order polynomial: 0.9285373880898892

# %%
adjusted_R_squared(m, k=2, r2=r2_2)
# Out:
# 0.928273200984861

# %%
# error vs predictor (residual plot)
plt.figure(figsize=(10,8))
plt.scatter(data['height'].values, y_p_2 - data['weight'].values)
plt.xlabel("Height")
plt.ylabel("error")
plt.show()

# %% [markdown]
# ## Third order polynomial

# %% [markdown]
# i.e. we are trying fit the equation:
#
# $$ y = \hat{\theta}_0 + \hat{\theta}_1 x + \hat{\theta}_2 x^2 + \hat{\theta}_3 x^3 $$
#
# Where $x$ is *height* and $y$ is *weight*.
#
# So, in order to achieve that:
#
# - $x_1 = x$
#
# - $x_2 = x^2$
#
# - $x_3 = x^3$
#
# Then the equation becomes
#
# $$ y = \hat{\theta}_0 + \hat{\theta}_1 x_1 + \hat{\theta}_2 x_2 + \hat{\theta}_3 x_3 $$
#
# Which can now be solved using Multiple Linear Regression

# %% [markdown]
# ### Prepare the data

# %%
x1 = data['height'].values
x2 = np.square(x1)
x3 = np.power(x1, 3)

# %% [markdown]
# $$X = [x1, x2, x3] $$

# %%
X = np.hstack((x1.reshape(-1,1), x2.reshape(-1,1), x3.reshape(-1,1)))

# %%
pd.DataFrame(X, columns=['height', 'height_square', 'height_cube'])
# Out:
#       height  height_square   height_cube
# 0    151.765   23032.615225  3.495545e+06
# 1    139.700   19516.090000  2.726398e+06
# 2    136.525   18639.075625  2.544700e+06
# 3    156.845   24600.354025  3.858443e+06
# 4    145.415   21145.522225  3.074876e+06
# ..       ...            ...           ...
# 539  145.415   21145.522225  3.074876e+06
# 540  162.560   26425.753600  4.295771e+06
# 541  156.210   24401.564100  3.811768e+06
# 542   71.120    5058.054400  3.597288e+05
# 543  158.750   25201.562500  4.000748e+06
#
# [544 rows x 3 columns]

# %% [markdown]
# ### Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
X_std = scaler.transform(X)

# %%
pd.DataFrame(X_std, columns=['height', 'height_square_std', 'height_cube_std'])
# Out:
#        height  height_square_std  height_cube_std
# 0    0.489588           0.470359         0.437671
# 1    0.052087          -0.053848        -0.159800
# 2   -0.063045          -0.184584        -0.300942
# 3    0.673799           0.704061         0.719568
# 4    0.259324           0.189051         0.110897
# ..        ...                ...              ...
# 539  0.259324           0.189051         0.110897
# 540  0.881037           0.976173         1.059283
# 541  0.650773           0.674428         0.683312
# 542 -2.434762          -2.209101        -1.998219
# 543  0.742878           0.793683         0.830111
#
# [544 rows x 3 columns]

# %% [markdown]
# ### fit the model

# %%
third_order_model = LinearRegression()

# %%
third_order_model.fit(X_std, y = data['weight'].values)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model parameters

# %%
third_order_model.intercept_
# Out:
# np.float64(35.61061759246321)

# %%
third_order_model.coef_
# Out:
# array([-25.68210297,  54.17561278, -14.63828595])

# %% [markdown]
# So the model looks like:
#
# $$\hat{weight} = 35.61 + (-25.68) \times height_{std} + (54.18) \times height^2_{std} + (-14.64) \times height^3_{std}$$

# %% [markdown]
# ### Model output

# %%
x_min = data['height'].min()
x_max = data['height'].max()
in_between_values = np.linspace(x_min, x_max, 100)

# %%
square_values = np.square(in_between_values)
cube_values = np.power(in_between_values, 3)

# %%
x_values = np.hstack((in_between_values.reshape(-1,1), square_values.reshape(-1,1), cube_values.reshape(-1,1)))

# %%
x_values_std = scaler.transform(x_values)

# %%
y_values_third_order = third_order_model.predict(x_values_std)

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(data=data, x='height', y='weight')
plt.plot(in_between_values, y_values_first_order, 'y--', label='First order Polynomial')
plt.plot(in_between_values, y_values_second_order, 'g--', label='Second order Polynomial')
plt.plot(in_between_values, y_values_third_order, color='r', label='Third order Polynomial')
plt.legend()
plt.grid()
plt.title("Weight vs Height", fontsize=16)
plt.xlabel("Height", fontsize=14)
plt.ylabel("Weight", fontsize=14)
plt.show()

# %% [markdown]
# ### Calculate coefficient of determination

# %%
y_p_3 = third_order_model.predict(X_std)

# %%
r2_3 = r2_score(y_true=data['weight'].values, y_pred=y_p_3)

print(f"Coefficient of determination for second order polynomial: {r2_3}")
# Out:
# Coefficient of determination for second order polynomial: 0.9289058038853012

# %%
adjusted_R_squared(m, k=3, r2=r2_3)
# Out:
# 0.9285108361291085

# %% [markdown]
# ## Observations
#
# - The first order polynomial doesn't fit the data well.
#
# - The second order polynomial does a good job in terms of fitting the data.
#
# - The third order polynomial is as good as second order polynomial in terms of fiiting the data.
#
# So we shall restrict ourselves to second order polynomial for this particular dataset.
