# %% [markdown]
# # Time Resampling, Shifting, Rolling and Expanding
#
# In this notebook we shall discuss about:
#
# - Time resampling
# - Time Shifting
# - Time rolling
# - TIme Expanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read the data

# %%
data = pd.read_csv("./starbucks.csv", index_col='Date', parse_dates = True)

# %%
data.head(20)
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# 2015-01-09  37.2361  27556706
# 2015-01-12  37.4415  10021486
# 2015-01-13  37.7401  11040702
# 2015-01-14  37.5301   9295084
# 2015-01-15  37.1381   8126602
# 2015-01-16  37.6188   9015502
# 2015-01-20  37.9058  10738304
# 2015-01-21  37.9361  10844182
# 2015-01-22  38.6128  23913056
# 2015-01-23  41.1702  38107194
# 2015-01-26  41.1235  14098574
# 2015-01-27  41.2262  10995808
# 2015-01-28  40.8645  11963202
# 2015-01-29  41.5575  12475860
# 2015-01-30  40.8482  10070456

# %% [markdown]
# *Close*: Closing stock price (last traded stock price) of Starbuck for each day
#
# *Volume*: Number of coffees sold in that particular day

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2015-01-02 to 2018-12-31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1006 non-null   float64
#  1   Volume  1006 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 23.6 KB

# %%
data['Close'].plot(figsize=(18,5), grid=True, title='Closing Stock Price of Starbucks');

# %%
data.tail()
# Out:
#             Close    Volume
# Date
# 2018-12-24  60.56   6323252
# 2018-12-26  63.08  16646238
# 2018-12-27  63.20  11308081
# 2018-12-28  63.39   7712127
# 2018-12-31  64.40   7690183

# %% [markdown]
# ## Time Resampling
#
# We shall be using DataFrame.resample() method in pandas.
#
# It takes **rule** parameter and then need to call an aggregate function.
#
# The **rule** parameter describes the frequency with which to apply the aggregation function (daily, monthly, yearly etc.)
#
# It is passed using offset alias. Reference of the same can be found in the [link](https://pandas.pydata.org/docs/user_guide/timeseries.html#offset-aliases)

# %%
data.resample(rule='YE').mean()  # Annual (Year-end) resampling with mean aggregation
# Out:
#                 Close        Volume
# Date
# 2015-12-31  50.078100  8.649190e+06
# 2016-12-31  53.891732  9.300633e+06
# 2017-12-31  55.457310  9.296078e+06
# 2018-12-31  56.870005  1.122883e+07

# %%
data.resample(rule='ME').mean()  # Month end resampling with mean aggregation
# Out:
#                 Close        Volume
# Date
# 2015-01-31  38.729470  1.336800e+07
# 2015-02-28  42.862432  7.908719e+06
# 2015-03-31  44.321836  8.905969e+06
# 2015-04-30  45.508914  8.540996e+06
# 2015-05-31  47.488650  6.723716e+06
# 2015-06-30  49.761627  6.856079e+06
# 2015-07-31  52.437959  8.087759e+06
# 2015-08-31  52.797976  1.064881e+07
# 2015-09-30  53.006186  8.935548e+06
# 2015-10-31  57.051373  8.893461e+06
# 2015-11-30  58.296355  7.077431e+06
# 2015-12-31  57.219514  7.952858e+06
# 2016-01-31  55.138963  1.383605e+07
# 2016-02-29  54.446810  1.119357e+07
# 2016-03-31  55.858968  8.203693e+06
# 2016-04-30  56.531200  9.407233e+06
# 2016-05-31  53.016571  7.849410e+06
# 2016-06-30  52.669300  8.495649e+06
# 2016-07-31  54.551905  1.018464e+07
# 2016-08-31  53.518291  7.797496e+06
# 2016-09-30  52.022771  9.178403e+06
# 2016-10-31  50.945319  7.073672e+06
# 2018-12-01  64.609474  1.316915e+07

# %%
data.resample(rule='QE').mean()
# Out:
#                 Close        Volume
# Date
# 2015-03-31  42.033705  1.005831e+07
# 2015-06-30  47.622476  7.375698e+06
# 2015-09-30  52.742539  9.206285e+06
# 2015-12-31  57.498228  8.002620e+06
# 2016-03-31  55.171702  1.093832e+07
# 2016-06-30  54.050434  8.582716e+06
# 2016-09-30  53.350578  8.996589e+06
# 2016-12-31  53.040917  8.753118e+06
# 2017-03-31  54.447013  9.846263e+06
# 2017-06-30  58.427046  8.131475e+06
# 2017-09-30  53.772141  1.017913e+07
# 2017-12-31  55.167005  9.036181e+06
# 2018-03-31  56.678044  1.093577e+07
# 2018-06-30  55.935744  1.043205e+07
# 2018-09-30  52.446013  9.849787e+06
# 2018-12-31  62.428954  1.370105e+07

# %%
data['Close'].resample(rule='QE').mean().plot.bar(figsize=(14,5))
# Out:
# <Axes: xlabel='Date'>

# %%
data['Volume'].resample(rule='YE').sum().plot.bar(figsize=(14,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Time Shifting

# %%
data['Close']
# Out:
# Date
# 2015-01-02    38.0061
# 2015-01-05    37.2781
# 2015-01-06    36.9748
# 2015-01-07    37.8848
# 2015-01-08    38.4961
#                ...
# 2018-12-24    60.5600
# 2018-12-26    63.0800
# 2018-12-27    63.2000
# 2018-12-28    63.3900
# 2018-12-31    64.4000
# Name: Close, Length: 1006, dtype: float64

# %% [markdown]
# ### Shifting down by 1 unit

# %%
data['Close: 1 day delay'] = data['Close'].shift(1)

# %%
data.head(10)
# Out:
#               Close    Volume  Close: 1 day delay
# Date
# 2015-01-02  38.0061   6906098                 NaN
# 2015-01-05  37.2781  11623796             38.0061
# 2015-01-06  36.9748   7664340             37.2781
# 2015-01-07  37.8848   9732554             36.9748
# 2015-01-08  38.4961  13170548             37.8848
# 2015-01-09  37.2361  27556706             38.4961
# 2015-01-12  37.4415  10021486             37.2361
# 2015-01-13  37.7401  11040702             37.4415
# 2015-01-14  37.5301   9295084             37.7401
# 2015-01-15  37.1381   8126602             37.5301

# %%
data.tail()
# Out:
#             Close    Volume  Close: 1 day delay
# Date
# 2018-12-24  60.56   6323252               61.39
# 2018-12-26  63.08  16646238               60.56
# 2018-12-27  63.20  11308081               63.08
# 2018-12-28  63.39   7712127               63.20
# 2018-12-31  64.40   7690183               63.39

# %%
data['Change in Close'] = data['Close'] - data['Close: 1 day delay']

# %%
data.head(10)
# Out:
#               Close    Volume  Close: 1 day delay  Change in Close
# Date
# 2015-01-02  38.0061   6906098                 NaN              NaN
# 2015-01-05  37.2781  11623796             38.0061          -0.7280
# 2015-01-06  36.9748   7664340             37.2781          -0.3033
# 2015-01-07  37.8848   9732554             36.9748           0.9100
# 2015-01-08  38.4961  13170548             37.8848           0.6113
# 2015-01-09  37.2361  27556706             38.4961          -1.2600
# 2015-01-12  37.4415  10021486             37.2361           0.2054
# 2015-01-13  37.7401  11040702             37.4415           0.2986
# 2015-01-14  37.5301   9295084             37.7401          -0.2100
# 2015-01-15  37.1381   8126602             37.5301          -0.3920

# %%
data['Change in Close'].plot(figsize = (14,5), title="Change in Closing stock price per day", grid=True)
# Out:
# <Axes: title={'center': 'Change in Closing stock price per day'}, xlabel='Date'>

# %%
data['Change in Close'].hist(bins=40, figsize=(10,8), edgecolor='k')
# Out:
# <Axes: >

# %% [markdown]
# ### Shifting down by k units

# %%
k = 7

data['Close: k days delay'] = data['Close'].shift(periods=k)

# %%
data.head(20)
# Out:
#               Close    Volume  Close: 1 day delay  Change in Close  \
# Date
# 2015-01-02  38.0061   6906098                 NaN              NaN
# 2015-01-05  37.2781  11623796             38.0061          -0.7280
# 2015-01-06  36.9748   7664340             37.2781          -0.3033
# 2015-01-07  37.8848   9732554             36.9748           0.9100
# 2015-01-08  38.4961  13170548             37.8848           0.6113
# 2015-01-09  37.2361  27556706             38.4961          -1.2600
# 2015-01-12  37.4415  10021486             37.2361           0.2054
# 2015-01-13  37.7401  11040702             37.4415           0.2986
# 2015-01-14  37.5301   9295084             37.7401          -0.2100
# 2015-01-15  37.1381   8126602             37.5301          -0.3920
# 2015-01-16  37.6188   9015502             37.1381           0.4807
# 2015-01-20  37.9058  10738304             37.6188           0.2870
# 2015-01-21  37.9361  10844182             37.9058           0.0303
# 2015-01-22  38.6128  23913056             37.9361           0.6767
# 2015-01-23  41.1702  38107194             38.6128           2.5574
# 2015-01-26  41.1235  14098574             41.1702          -0.0467
# 2015-01-27  41.2262  10995808             41.1235           0.1027
# 2015-01-28  40.8645  11963202             41.2262          -0.3617
# 2015-01-29  41.5575  12475860             40.8645           0.6930
# 2015-01-30  40.8482  10070456             41.5575          -0.7093
#
#             Close: k days delay
# Date
# 2015-01-02                  NaN
# 2015-01-05                  NaN
# 2015-01-06                  NaN
# 2015-01-07                  NaN
# 2015-01-08                  NaN
# 2015-01-09                  NaN
# 2015-01-12                  NaN
# 2015-01-13              38.0061
# 2015-01-14              37.2781
# 2015-01-15              36.9748
# 2015-01-16              37.8848
# 2015-01-20              38.4961
# 2015-01-21              37.2361
# 2015-01-22              37.4415
# 2015-01-23              37.7401
# 2015-01-26              37.5301
# 2015-01-27              37.1381
# 2015-01-28              37.6188
# 2015-01-29              37.9058
# 2015-01-30              37.9361

# %%
(data['Close'] - data['Close: k days delay']).plot(figsize=(14,5), grid=True)
# Out:
# <Axes: xlabel='Date'>

# %%
(data['Close'] - data['Close: k days delay']).hist(bins=10, figsize=(10,8), edgecolor='k')
# Out:
# <Axes: >

# %% [markdown]
# ### Shifting up by 1 unit
#
# Shifting up by 1 unit is putting the perod = -1

# %%
data['Close: 1 day lead'] = data['Close'].shift(-1)

# %%
data[['Close', 'Close: 1 day lead']].head(10)
# Out:
#               Close  Close: 1 day lead
# Date
# 2015-01-02  38.0061            37.2781
# 2015-01-05  37.2781            36.9748
# 2015-01-06  36.9748            37.8848
# 2015-01-07  37.8848            38.4961
# 2015-01-08  38.4961            37.2361
# 2015-01-09  37.2361            37.4415
# 2015-01-12  37.4415            37.7401
# 2015-01-13  37.7401            37.5301
# 2015-01-14  37.5301            37.1381
# 2015-01-15  37.1381            37.6188

# %%
data[['Close', 'Close: 1 day lead']].tail(10)
# Out:
#             Close  Close: 1 day lead
# Date
# 2018-12-17  64.47              64.92
# 2018-12-18  64.92              64.06
# 2018-12-19  64.06              62.15
# 2018-12-20  62.15              61.39
# 2018-12-21  61.39              60.56
# 2018-12-24  60.56              63.08
# 2018-12-26  63.08              63.20
# 2018-12-27  63.20              63.39
# 2018-12-28  63.39              64.40
# 2018-12-31  64.40                NaN

# %% [markdown]
# ### Shifting up by k units

# %%
k = 7

data['Close: k days lead'] = data['Close'].shift(periods=(-1)*k)

# %%
data[['Close', 'Close: k days lead']].head(20)
# Out:
#               Close  Close: k days lead
# Date
# 2015-01-02  38.0061             37.7401
# 2015-01-05  37.2781             37.5301
# 2015-01-06  36.9748             37.1381
# 2015-01-07  37.8848             37.6188
# 2015-01-08  38.4961             37.9058
# 2015-01-09  37.2361             37.9361
# 2015-01-12  37.4415             38.6128
# 2015-01-13  37.7401             41.1702
# 2015-01-14  37.5301             41.1235
# 2015-01-15  37.1381             41.2262
# 2015-01-16  37.6188             40.8645
# 2015-01-20  37.9058             41.5575
# 2015-01-21  37.9361             40.8482
# 2015-01-22  38.6128             41.0629
# 2015-01-23  41.1702             41.4469
# 2015-01-26  41.1235             41.5453
# 2015-01-27  41.2262             41.9856
# 2015-01-28  40.8645             41.6858
# 2015-01-29  41.5575             41.6015
# 2015-01-30  40.8482             42.7069

# %%
data[['Close', 'Close: k days lead']].tail(20)
# Out:
#             Close  Close: k days lead
# Date
# 2018-11-30  66.72               66.13
# 2018-12-03  67.50               66.91
# 2018-12-04  66.65               65.34
# 2018-12-06  66.55               64.47
# 2018-12-07  65.47               64.92
# 2018-12-10  65.49               64.06
# 2018-12-11  65.92               62.15
# 2018-12-12  66.13               61.39
# 2018-12-13  66.91               60.56
# 2018-12-14  65.34               63.08
# 2018-12-17  64.47               63.20
# 2018-12-18  64.92               63.39
# 2018-12-19  64.06               64.40
# 2018-12-20  62.15                 NaN
# 2018-12-21  61.39                 NaN
# 2018-12-24  60.56                 NaN
# 2018-12-26  63.08                 NaN
# 2018-12-27  63.20                 NaN
# 2018-12-28  63.39                 NaN
# 2018-12-31  64.40                 NaN

# %% [markdown]
# ## Time rolling

# %%
data['Close: rolling avg 7 days'] = data['Close'].rolling(window=7).mean()   # Simple Moving Average with 7 days

data['Close: rolling avg 30 days'] = data['Close'].rolling(window=30).mean() # Simple Moving Average with 30 days

# %%
data[['Close', 'Close: rolling avg 7 days', 'Close: rolling avg 30 days']].plot(figsize=(12,5), grid= True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Time Expanding

# %%
data['Close: expanding sum'] = data['Close'].expanding().sum()
data['Close: expanding avg'] = data['Close'].expanding().mean()

# %%
data[['Close','Close: expanding sum', 'Close: expanding avg']].head(20)
# Out:
#               Close  Close: expanding sum  Close: expanding avg
# Date
# 2015-01-02  38.0061               38.0061             38.006100
# 2015-01-05  37.2781               75.2842             37.642100
# 2015-01-06  36.9748              112.2590             37.419667
# 2015-01-07  37.8848              150.1438             37.535950
# 2015-01-08  38.4961              188.6399             37.727980
# 2015-01-09  37.2361              225.8760             37.646000
# 2015-01-12  37.4415              263.3175             37.616786
# 2015-01-13  37.7401              301.0576             37.632200
# 2015-01-14  37.5301              338.5877             37.620856
# 2015-01-15  37.1381              375.7258             37.572580
# 2015-01-16  37.6188              413.3446             37.576782
# 2015-01-20  37.9058              451.2504             37.604200
# 2015-01-21  37.9361              489.1865             37.629731
# 2015-01-22  38.6128              527.7993             37.699950
# 2015-01-23  41.1702              568.9695             37.931300
# 2015-01-26  41.1235              610.0930             38.130812
# 2015-01-27  41.2262              651.3192             38.312894
# 2015-01-28  40.8645              692.1837             38.454650
# 2015-01-29  41.5575              733.7412             38.617958
# 2015-01-30  40.8482              774.5894             38.729470

# %%
data[['Close','Close: expanding avg']].plot(figsize=(12,5), grid = True);
