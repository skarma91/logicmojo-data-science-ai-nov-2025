# %% [markdown]
# # ETS Decomposition
#
# ETS stands for Error-Trend-Seasionality.
#
# ETS decomposition is the method to extract error (residues), trend and seasonal components from a time-series data.

# %% [markdown]
# # Seasonal Decomposition

# %% [markdown]
# ## Read the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
airline_data = pd.read_csv("./airline_passengers.csv", index_col='Month', parse_dates=True)

# %%
airline_data.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
airline_data.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
airline_data['Thousands of Passengers'].plot(figsize=(12,5), title="Airline Passenger", grid=True);

# %% [markdown]
# **Observations**
#
# - The number of passengers travelling by airlines are increasing exponentially (there is a non-linear trend)
# - The data has a clear seasonal component.
#     - The peak in each year is happening during summer
#     - The trough in each year is happening in winter
#     - The data is seasonal with period = 1 year

# %% [markdown]
# ## Seasonal Decompose

# %% [markdown]
# For additive model:
#
# $$ y_t = T_t + S_t + C_t + \epsilon_t $$
#
# For multiplicative model:
#
# $$ y_t = T_t \times S_t \times C_t \times \epsilon_t $$

# %% [markdown]
# **Note:** We need to install `statsmodels` library. Run the following command in your virtual environment.
#
# `pip install statsmodels`

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(airline_data['Thousands of Passengers'], model='multiplicative') # because the data has non-linear trends

# %%
result.plot();

# %%
# let's check additive models too

result_add = seasonal_decompose(airline_data['Thousands of Passengers'], model='additive')

# %%
result_add.plot();

# %% [markdown]
# As we are using additive model over a dataset where non-linear trend is evident, we can see a higher residues in the seasonal decompose of additive model.

# %% [markdown]
# ## Simple moving averages

# %%
airline_data['SMA-6'] = airline_data['Thousands of Passengers'].rolling(window=6).mean()

airline_data['SMA-12'] = airline_data['Thousands of Passengers'].rolling(window=12).mean()

# %%
airline_data.head(20)
# Out:
#             Thousands of Passengers       SMA-6      SMA-12
# Month
# 1949-01-01                      112         NaN         NaN
# 1949-02-01                      118         NaN         NaN
# 1949-03-01                      132         NaN         NaN
# 1949-04-01                      129         NaN         NaN
# 1949-05-01                      121         NaN         NaN
# 1949-06-01                      135  124.500000         NaN
# 1949-07-01                      148  130.500000         NaN
# 1949-08-01                      148  135.500000         NaN
# 1949-09-01                      136  136.166667         NaN
# 1949-10-01                      119  134.500000         NaN
# 1949-11-01                      104  131.666667         NaN
# 1949-12-01                      118  128.833333  126.666667
# 1950-01-01                      115  123.333333  126.916667
# 1950-02-01                      126  119.666667  127.583333
# 1950-03-01                      141  120.500000  128.333333
# 1950-04-01                      135  123.166667  128.833333
# 1950-05-01                      125  126.666667  129.166667
# 1950-06-01                      149  131.833333  130.333333
# 1950-07-01                      170  141.000000  132.166667
# 1950-08-01                      170  148.333333  134.000000

# %%
airline_data.plot(figsize=(12,5), grid=True, title='Airline Passenger Data')
# Out:
# <Axes: title={'center': 'Airline Passenger Data'}, xlabel='Month'>

# %% [markdown]
# ## Exponentially weighted moving average (EWMA)
#
# We will use [pandas.DataFrame.ewm()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) method to calculate EWMA of a time series data.

# %% [markdown]
# This method has a boolean parameter called 'adjust'.
#
# if *adjust = True* then:
#
# $$y_t = \frac{x_t+(1-\alpha)x_{t-1}+(1-\alpha)^2x_{t-2}+(1-\alpha)^3x_{t-3}+...+(1-\alpha)^tx_{0}}{1+(1-\alpha)+(1-\alpha)^2+(1-\alpha)^3+...+(1-\alpha)^t} = \frac{\sum_{i=0}^{t}(1-\alpha)^i x_{t-i}}{\sum_{i=0}^{t}(1-\alpha)^i}$$

# %% [markdown]
# if *adjust = False* then:
#
# $$ y_0 = x_0, \newline y_t = (1-\alpha)y_{t-1} + \alpha x_t $$
#
#
# $\alpha$ is called the smoothing parameter. The value of $\alpha$ lies between 0 and 1. $[0 \leq \alpha \leq 1]$

# %%
airline_data['EWMA-adj-False'] = airline_data['Thousands of Passengers'].ewm(alpha=0.75, adjust=False).mean()

airline_data['EWMA-adj-True'] = airline_data['Thousands of Passengers'].ewm(alpha=0.75, adjust= True).mean()

# %%
airline_data.plot(figsize=(12,5), grid=True, title='Airline Passenger Data')
# Out:
# <Axes: title={'center': 'Airline Passenger Data'}, xlabel='Month'>

# %% [markdown]
# EWMA with adj=True and EWMA with adj = False don't have much diffenrences in values.

# %%
airline_data.head(20)
# Out:
#             Thousands of Passengers       SMA-6      SMA-12  EWMA-adj-False  \
# Month
# 1949-01-01                      112         NaN         NaN      112.000000
# 1949-02-01                      118         NaN         NaN      116.500000
# 1949-03-01                      132         NaN         NaN      128.125000
# 1949-04-01                      129         NaN         NaN      128.781250
# 1949-05-01                      121         NaN         NaN      122.945312
# 1949-06-01                      135  124.500000         NaN      131.986328
# 1949-07-01                      148  130.500000         NaN      143.996582
# 1949-08-01                      148  135.500000         NaN      146.999146
# 1949-09-01                      136  136.166667         NaN      138.749786
# 1949-10-01                      119  134.500000         NaN      123.937447
# 1949-11-01                      104  131.666667         NaN      108.984362
# 1949-12-01                      118  128.833333  126.666667      115.746090
# 1950-01-01                      115  123.333333  126.916667      115.186523
# 1950-02-01                      126  119.666667  127.583333      123.296631
# 1950-03-01                      141  120.500000  128.333333      136.574158
# 1950-04-01                      135  123.166667  128.833333      135.393539
# 1950-05-01                      125  126.666667  129.166667      127.598385
# 1950-06-01                      149  131.833333  130.333333      143.649596
# 1950-07-01                      170  141.000000  132.166667      163.412399
# 1950-08-01                      170  148.333333  134.000000      168.353100
#
#             EWMA-adj-True
# Month
# 1949-01-01     112.000000
# 1949-02-01     116.800000
# 1949-03-01     128.380952
# 1949-04-01     128.847059
# 1949-05-01     122.956012
# 1949-06-01     131.991209
# 1949-07-01     143.998535
# 1949-08-01     146.999680
# 1949-09-01     138.749888
# 1949-10-01     123.937458
# 1949-11-01     108.984361
# 1949-12-01     115.746091
# 1950-01-01     115.186523
# 1950-02-01     123.296631
# 1950-03-01     136.574158
# 1950-04-01     135.393539
# 1950-05-01     127.598385
# 1950-06-01     143.649596
# 1950-07-01     163.412399
# 1950-08-01     168.353100

# %%
airline_data['EWMA_span_1'] = airline_data['Thousands of Passengers'].ewm(span=1, adjust=True).mean()
airline_data['EWMA_span_6'] = airline_data['Thousands of Passengers'].ewm(span=6, adjust=True).mean()
airline_data['EWMA_span_12'] = airline_data['Thousands of Passengers'].ewm(span=12, adjust=True).mean()

# %%
airline_data.head(20)
# Out:
#             Thousands of Passengers       SMA-6      SMA-12  EWMA-adj-False  \
# Month
# 1949-01-01                      112         NaN         NaN      112.000000
# 1949-02-01                      118         NaN         NaN      116.500000
# 1949-03-01                      132         NaN         NaN      128.125000
# 1949-04-01                      129         NaN         NaN      128.781250
# 1949-05-01                      121         NaN         NaN      122.945312
# 1949-06-01                      135  124.500000         NaN      131.986328
# 1949-07-01                      148  130.500000         NaN      143.996582
# 1949-08-01                      148  135.500000         NaN      146.999146
# 1949-09-01                      136  136.166667         NaN      138.749786
# 1949-10-01                      119  134.500000         NaN      123.937447
# 1949-11-01                      104  131.666667         NaN      108.984362
# 1949-12-01                      118  128.833333  126.666667      115.746090
# 1950-01-01                      115  123.333333  126.916667      115.186523
# 1950-02-01                      126  119.666667  127.583333      123.296631
# 1950-03-01                      141  120.500000  128.333333      136.574158
# 1950-04-01                      135  123.166667  128.833333      135.393539
# 1950-05-01                      125  126.666667  129.166667      127.598385
# 1950-06-01                      149  131.833333  130.333333      143.649596
# 1950-07-01                      170  141.000000  132.166667      163.412399
# 1950-08-01                      170  148.333333  134.000000      168.353100
#
#             EWMA-adj-True  EWMA_span_6  EWMA_span_12  EWMA_span_1
# Month
# 1949-01-01     112.000000   112.000000    112.000000        112.0
# 1949-02-01     116.800000   115.500000    115.250000        118.0
# 1949-03-01     128.380952   122.917431    121.787529        132.0
# 1949-04-01     128.847059   125.266892    124.064224        129.0
# 1949-05-01     122.956012   123.769332    123.231685        121.0
# 1949-06-01     131.991209   127.469517    126.092005        135.0
# 1949-07-01     143.998535   133.950151    130.980697        148.0
# 1949-08-01     146.999680   138.256171    134.532364        148.0
# 1949-09-01     138.749888   137.578764    134.822714        136.0
# 1949-10-01     123.937458   132.080461    131.824316        119.0
# 1949-11-01     108.984361   123.854336    126.733137        104.0
# 1949-12-01     115.746091   122.151635    125.180414        118.0
# 1950-01-01     115.186523   120.082239    123.412707        115.0
# 1950-02-01     123.296631   121.788382    123.853241        126.0
# 1950-03-01     136.574158   127.312928    126.725616        141.0
# 1950-04-01     135.393539   129.519365    128.093024        135.0
# 1950-05-01     127.598385   128.223869    127.587644        125.0
# 1950-06-01     143.649596   134.173845    131.053193        149.0
# 1950-07-01     163.412399   144.427046    137.306620        170.0
# 1950-08-01     168.353100   151.742347    142.520951        170.0

# %%
airline_data[['Thousands of Passengers','EWMA_span_6', 'EWMA_span_12']].plot(figsize=(12,5), grid=True, title='Airline Passenger Data');
