# %% [markdown]
# # Date-time formats in Python

# %% [markdown]
# ## DateTime library

# %%
from datetime import datetime

# %%
year = 2024
month = 11
day = 2
hour = 17 # this is in 24 hour format (17 means 5 PM)
mins = 34
secs = 23

# %%
datetime(year, month, day)
# Out:
# datetime.datetime(2024, 11, 2, 0, 0)

# %%
my_date = datetime(year, month, day, hour, mins, secs)

# %%
my_date
# Out:
# datetime.datetime(2024, 11, 2, 17, 34, 23)

# %%
type(my_date)
# Out:
# datetime.datetime

# %%
my_date.day  # returns the day of the month
# Out:
# 2

# %%
my_date.month # returns the month of the year
# Out:
# 11

# %%
my_date.date()
# Out:
# datetime.date(2024, 11, 2)

# %%
my_date.time()
# Out:
# datetime.time(17, 34, 23)

# %%
my_date.strftime("%Y-%m-%d-%H-%M-%S")  # string format of date
# Out:
# '2024-11-02-17-34-23'

# %%
my_date.strftime("time: %H-%M-%S  and date: %d-%m-%Y")
# Out:
# 'time: 17-34-23  and date: 02-11-2024'

# %%
import time
import numpy as np

def program():
    a = np.random.randint(0, 1000000, size=50000000)
    a.sort()
    return

# %%
strtime = datetime.now()

program()

endtime = datetime.now()

# %%
print(f"The execution time of the program is: {endtime - strtime}s")
# Out:
# The execution time of the program is: 0:00:00.787065s

# %%
date_string = "2023-10-27 14:30:45"

format_string = "%Y-%m-%d %H:%M:%S"

date_time = datetime.strptime(date_string, format_string)

date_time
# Out:
# datetime.datetime(2023, 10, 27, 14, 30, 45)

# %%
date_string = "2023/10/27"

format_string = "%Y/%m/%d"

date_time = datetime.strptime(date_string, format_string)

date_time
# Out:
# datetime.datetime(2023, 10, 27, 0, 0)

# %% [markdown]
# ## datetime64 format in numpy
#
# The number 64 here specifies the 64 bit format. (8 bytes to store the data)

# %%
np.array(['2020-06-01', '2020-07-01', '2020-08-01'], dtype='datetime64')
# Out:
# array(['2020-06-01', '2020-07-01', '2020-08-01'], dtype='datetime64[D]')

# %%
np.array(['2020-06-01', '2021-07-01', '2022-08-01'], dtype='datetime64[D]')
# Out:
# array(['2020-06-01', '2021-07-01', '2022-08-01'], dtype='datetime64[D]')

# %%
np.array(['2020-06-01T06:34:56', '2021-07-01T12:21:39', '2022-08-01T20:45:01'], dtype='datetime64[ms]')
# Out:
# array(['2020-06-01T06:34:56.000', '2021-07-01T12:21:39.000',
#        '2022-08-01T20:45:01.000'], dtype='datetime64[ms]')

# %% [markdown]
# ## Creating a range of dates in numpy

# %%
np.arange(2, 20, 3)
# Out:
# array([ 2,  5,  8, 11, 14, 17])

# %%
np.arange('2020-03-12','2020-05-31', 7, dtype='datetime64[D]')
# Out:
# array(['2020-03-12', '2020-03-19', '2020-03-26', '2020-04-02',
#        '2020-04-09', '2020-04-16', '2020-04-23', '2020-04-30',
#        '2020-05-07', '2020-05-14', '2020-05-21', '2020-05-28'],
#       dtype='datetime64[D]')

# %%
np.arange('2022-01-01', '2023-01-01', 3, dtype='datetime64[M]')
# Out:
# array(['2022-01', '2022-04', '2022-07', '2022-10'], dtype='datetime64[M]')

# %% [markdown]
# ## Creating date ranges in Pandas

# %%
import pandas as pd

# %%
time = datetime.now()

# %%
time = time.strftime("%Y-%m-%d")

# %%
time
# Out:
# '2026-05-23'

# %%
pd.date_range(time, periods=10, freq='QE')   # QE -> Quarter End
# Out:
# DatetimeIndex(['2026-06-30', '2026-09-30', '2026-12-31', '2027-03-31',
#                '2027-06-30', '2027-09-30', '2027-12-31', '2028-03-31',
#                '2028-06-30', '2028-09-30'],
#               dtype='datetime64[ns]', freq='QE-DEC')

# %%
pd.date_range(time, periods=10, freq='ME') # ME -> Month End
# Out:
# DatetimeIndex(['2026-05-31', '2026-06-30', '2026-07-31', '2026-08-31',
#                '2026-09-30', '2026-10-31', '2026-11-30', '2026-12-31',
#                '2027-01-31', '2027-02-28'],
#               dtype='datetime64[ns]', freq='ME')

# %% [markdown]
# ## Datetime index in pandas

# %%
pd.to_datetime(['2022---02---07', '2022---04---05'],format="%Y---%m---%d")
# Out:
# DatetimeIndex(['2022-02-07', '2022-04-05'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['2022-03-05', '2022-03-05'])
# Out:
# DatetimeIndex(['2022-03-05', '2022-03-05'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['2022-03-05', '6th Mar,2022'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 pd.to_datetime(['2022-03-05', '6th Mar,2022'])
#
# File c:\Users\Sourav Karmakar\Desktop\Work\LogicMojo\logicmojo-data-science-ai-nov-2025\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:1104, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1102         result = _convert_and_box_cache(argc, cache_array)
#    1103     else:
# -> 1104         result = convert_listlike(argc, format)
#    1105 else:
#    1106     result = convert_listlike(np.array([arg]), format)[0]
#
# File c:\Users\Sourav Karmakar\Desktop\Work\LogicMojo\logicmojo-data-science-ai-nov-2025\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File c:\Users\Sourav Karmakar\Desktop\Work\LogicMojo\logicmojo-data-science-ai-nov-2025\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "6th Mar,2022" doesn't match format "%Y-%m-%d", at position 1. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %% [markdown]
# ## Create a dataframe with datetime index in pandas

# %%
data = np.random.randn(15, 3)

# %%
cols = ['A', 'B', 'C']

# %%
idx = pd.date_range('2025-01-01', periods=15, freq='D')

# %%
df = pd.DataFrame(data, columns=cols, index=idx)

# %%
df
# Out:
#                    A         B         C
# 2025-01-01 -0.302245  1.231254 -1.175096
# 2025-01-02  0.193598  0.811118  0.745230
# 2025-01-03  0.324506  2.216133 -0.315052
# 2025-01-04 -1.416068 -1.318566 -0.599018
# 2025-01-05  1.594949  0.991375  0.384655
# 2025-01-06  1.456129  1.707136 -1.082154
# 2025-01-07 -0.882702  1.824544  0.815313
# 2025-01-08 -0.440570  0.526915  0.951706
# 2025-01-09  0.079734 -1.328454  1.033456
# 2025-01-10  0.154696 -2.657841  0.125362
# 2025-01-11 -1.950751  1.741280  0.123260
# 2025-01-12 -0.332269  1.889408 -0.614976
# 2025-01-13 -1.614515 -0.647196 -1.581641
# 2025-01-14  0.886514  0.073752 -1.876954
# 2025-01-15  0.021120  1.296347 -1.148615

# %%
df.index.max()
# Out:
# Timestamp('2025-01-15 00:00:00')

# %% [markdown]
# ## Importing a time series data in pandas and analyzing it

# %%
data = pd.read_csv("./DailyTotalFemaleBirths.csv")

# %%
data.head(10)
# Out:
#         Date  Births
# 0   1/1/1959      35
# 1   1/2/1959      32
# 2   1/3/1959      30
# 3   1/4/1959      31
# 4   1/5/1959      44
# 5   1/6/1959      29
# 6   1/7/1959      45
# 7   1/8/1959      43
# 8   1/9/1959      38
# 9  1/10/1959      27

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    object
#  1   Births  365 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %% [markdown]
# We want *Date* to be used as index

# %%
dates = pd.to_datetime(data['Date'])

# %%
data.index = dates

# %%
del data['Date']

# %%
data
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %% [markdown]
# ## Plot the time series data

# %% [markdown]
# ### Using matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 8))
plt.plot(data['Births'])
plt.grid()
plt.xlabel("Dates")
plt.ylabel("Number of Births")
plt.title("Number of female births", fontsize=14)
plt.show()

# %% [markdown]
# ### Using native plot method in pandas dataframe

# %%
data.plot(y='Births', kind='line', figsize=(10,8), xlabel='Dates', ylabel='Numbers', title='Female births', grid=True);

# %%
df
# Out:
#                    A         B         C
# 2025-01-01 -0.302245  1.231254 -1.175096
# 2025-01-02  0.193598  0.811118  0.745230
# 2025-01-03  0.324506  2.216133 -0.315052
# 2025-01-04 -1.416068 -1.318566 -0.599018
# 2025-01-05  1.594949  0.991375  0.384655
# 2025-01-06  1.456129  1.707136 -1.082154
# 2025-01-07 -0.882702  1.824544  0.815313
# 2025-01-08 -0.440570  0.526915  0.951706
# 2025-01-09  0.079734 -1.328454  1.033456
# 2025-01-10  0.154696 -2.657841  0.125362
# 2025-01-11 -1.950751  1.741280  0.123260
# 2025-01-12 -0.332269  1.889408 -0.614976
# 2025-01-13 -1.614515 -0.647196 -1.581641
# 2025-01-14  0.886514  0.073752 -1.876954
# 2025-01-15  0.021120  1.296347 -1.148615

# %%
ax = df.plot(y='A', kind='line', c='r', label='A', figsize=(6,5), xlabel='Dates', ylabel='values', title='Multiple Time Series', grid=True)
ax.plot(df['B'], c='b', label='B')
ax.plot(df['C'], c='g', label='C')
plt.legend()
plt.show()
# Out:
# C:\Users\Sourav Karmakar\AppData\Local\Temp\ipykernel_22868\2474740976.py:2: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   ax.plot(df['B'], c='b', label='B')
