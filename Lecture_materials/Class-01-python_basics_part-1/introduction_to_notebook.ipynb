# %% [markdown]
# # Heading-1
#
# ## Heading-2
#
# ### Heading-3
#
# #### Heading-4
#
# ##### Heading-5

# %% [markdown]
# ### First python code

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Play around with markdown
#
# In this noteboook we shall explore some cool features of MarkDown.
#
# Convert from markdown to code cell [shortcut]: esc + y
#
# Convert from code cell to makdown [shortcut]: esc + m
#
# To run any cell : shift + enter

# %% [markdown]
# this **statement is in bold**.
#
# this is also __a bold statement__.
#
# this is *italic text*.
#
# this is also an _italic text_.
#
# this statement is **_bold and italicized_**.

# %% [markdown]
# ### You can also run terminal commands in code cell

# %%
# !mkdir new_directory

# %% [markdown]
# ### Quotes in markdown
#
# > "To err is Human, to forgive is divine"

# %% [markdown]
# ### Ordered list in makdown
#
# 1. Python is a computer programming language
# 1. Python is an interpreted language
# 1. Python was created in the year 1991
# 1. Python was created by Guido Van Rossum
# 1. Currently the laest python version is 3.14
# 1. Python is widelyused for ML
# 1. Python is also used for web development

# %% [markdown]
# ### Unordered list [bullet points]
#
# List of few useful python packages for data science
#
# - NumPy
# - SciPy
# - Scikit Learn
# - Pandas

# %% [markdown]
# ### Nested list
#
# We are going to cover following topics in ML
#
# - Supervised Learning
#     1. linear regresssion
#     1. logistic regression
#     1. tree based models
# - Unsupervised Learning
#     1. Clustering
#     1. Dimensionality Reduction

# %% [markdown]
# ### HyperLinks
#
# To learn more about markdown [visit this page](https://www.markdownguide.org/basic-syntax/)

# %% [markdown]
# ### Inserting Image
#
# ![alt text](path of the image)
#
# ![python_logo](Python-Logo.jpg)
#
# ![lm_10](data:image/jpeg;base64,...)

# %% [markdown]
# ### Code blocks
#
# ```python
# import numpy as np
#
# np.random.randint(3,4,5)
#
# ```
#
# ```json
#
# {
#     "x": 1,
#     "y": 2,
#     "z": 3,
# }
# ```
#
# single code
#
# `this is my code`

# %% [markdown]
# ### Table in markdwon
#
# | Fruit | Price |
# |:-------:|-------:|
# | apple   | 140     |
# | banana  | 50      |
# | Orange  | 100     |

# %% [markdown]
# ### Mathematical Equations / Symbols (LaTex)
#
# $ E = mc^2 $
#
# $$ x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a} $$
