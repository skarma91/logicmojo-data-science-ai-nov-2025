# %%
import numpy as np
import math
import statistics as stat

# %% [markdown]
# NumPy random module documentation: https://numpy.org/doc/stable/reference/random/legacy.html

# %%
## seed of random number generation

np.random.seed(4567)    # helps us to reproduce the same set of random numbers
np.random.rand(5)
# Out:
# array([0.36197172, 0.98443376, 0.86919658, 0.69638201, 0.70749086])

# %%
np.random.rand(5)
# Out:
# array([0.12073251, 0.20883314, 0.24408008, 0.59224837, 0.88436908])

# %% [markdown]
# ### `np.random.rand(shape)`
#
# This generates random float numbers between [0, 1). The values are drawn from uniform distribution.
#
# A NumPy array of given `shape` is generated.

# %%
np.random.rand(100)
# Out:
# array([0.82492654, 0.348714  , 0.2600929 , 0.57459279, 0.38183625,
#        0.91288837, 0.93400136, 0.60432362, 0.75044715, 0.40792436,
#        0.00460304, 0.96668852, 0.25591158, 0.24840153, 0.17864275,
#        0.64165643, 0.75296833, 0.66710363, 0.28161888, 0.45195252,
#        0.47419969, 0.81132425, 0.67424887, 0.02884469, 0.95832241,
#        0.90058748, 0.6356059 , 0.37196996, 0.16536309, 0.88442025,
#        0.35081466, 0.68985655, 0.58297855, 0.23425193, 0.01180308,
#        0.58399257, 0.10901466, 0.66114655, 0.25837536, 0.52916702,
#        0.9668595 , 0.76929762, 0.87380108, 0.62960859, 0.2016795 ,
#        0.52636039, 0.33417941, 0.86916724, 0.87219793, 0.72416775,
#        0.66651354, 0.43422412, 0.11678664, 0.3689837 , 0.46328341,
#        0.35729204, 0.23524712, 0.24075634, 0.50093497, 0.95153173,
#        0.24485991, 0.47038641, 0.16354352, 0.40894623, 0.97986087,
#        0.67848712, 0.41614299, 0.06364473, 0.51655648, 0.97406915,
#        0.54590709, 0.02467369, 0.26135924, 0.53585288, 0.95395928,
#        0.97406342, 0.77009983, 0.28555941, 0.08138442, 0.19345776,
#        0.34891395, 0.12863137, 0.94287017, 0.1021511 , 0.78511626,
#        0.94832275, 0.18504948, 0.89891231, 0.61372295, 0.74645028,
#        0.95908332, 0.55794517, 0.56584404, 0.0998431 , 0.41948049,
#        0.33454486, 0.19126588, 0.15041314, 0.2853481 , 0.38916977])

# %%
np.random.rand(4, 5)
# Out:
# array([[0.22906146, 0.20320903, 0.17973632, 0.12360917, 0.29851527],
#        [0.05302845, 0.58202423, 0.4816768 , 0.89764031, 0.58036997],
#        [0.2369879 , 0.83443044, 0.2610987 , 0.51636448, 0.08901816],
#        [0.15237192, 0.11076915, 0.441496  , 0.54935138, 0.68980372]])

# %%
np.random.rand(3,2,5)
# Out:
# array([[[0.04354413, 0.74679451, 0.27392904, 0.29095106, 0.80598471],
#         [0.33952704, 0.66825768, 0.5127312 , 0.64772944, 0.31287162]],
#
# Out:
# array([[ 1.44106681,  0.55020584,  0.98728947],
#        [ 0.53779126, -1.57680032,  0.10029992],
#        [ 1.71629653,  0.0913306 ,  1.51678088],
#        [ 0.81927247,  0.17354251, -0.52326472],
#        [-0.23992411,  0.45838851,  0.00782789]])

# %% [markdown]
# ### np.random.randint(a,b,shape)
#
# a random integer number generator.
#
# a NumPy array of given `shape` is generated with random integer from `a` to `b` (excluding `b`)

# %%
np.random.randint(0, 10, 5)
# Out:
# array([9, 8, 1, 5, 9], dtype=int32)

# %%
np.random.randint(0, 10, (5, 4))
# Out:
# array([[6, 8, 7, 8],
#        [5, 2, 8, 1],
#        [6, 4, 8, 4],
#        [6, 4, 9, 1],
#        [6, 8, 8, 1]], dtype=int32)

# %% [markdown]
# ### Helper function to plot the histogram

# %%
import matplotlib.pyplot as plt

def plot_hist(x, edgecolor='k', nbins=20):
    plt.figure(figsize=(10,8))
    plt.hist(x, edgecolor=edgecolor, bins=nbins)
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.show()

# %%
### uniformly distributed random values

values = np.random.rand(100000) # random numbers are uniformly distributed b/w 0 and 1

plot_hist(values, 'k', 20)

# %%
values = np.random.uniform(2, 6, 100000) # random numbers are uniformly distributed b/w 2 and 6

plot_hist(values)

# %%
### Normally distributed random variable

values = np.random.randn(10000) # the random numbers are normally distributed with mean 0 and std dev 1

plot_hist(values)

# %%
### mean = 5, std dev = 2

values = np.random.normal(loc=5, scale=2, size=10000) # the random numbers are normally distributed with mean 5 and std dev 2

plot_hist(values)

# %%
import seaborn as sns

# %%
sns.histplot(values, kde=True)  # kde stands for kernel density estimation, produces a smooth curve
# Out:
# <Axes: ylabel='Count'>

# %%
### random integers from uniform discrete distribution

# np.random.randint(a, b, size) --- random integer values between a to b-1
# np.random.randint(6, size=5) ---- as a is not given, it will consider a=0, it will produce random integers between 0 to 5

np.random.randint(6, size=5)   ### 5 values between 0 to 5
# Out:
# array([5, 4, 5, 1, 5], dtype=int32)

# %%
np.random.randint(2, 10, 5)  ### 5 random values between the range 2 to 9
# Out:
# array([5, 8, 4, 7, 8], dtype=int32)

# %%
values = [3, 4, 1, 5, 3, 5, 6, 1, 2, 4, 2]

from collections import Counter
count_values = Counter(values)
count_values
# Out:
# Counter({3: 2, 4: 2, 1: 2, 5: 2, 2: 2, 6: 1})

# %%
def plot_bar(x):

    from collections import Counter

    count_dict = Counter(x)

    sorted_counts = sorted(count_dict.items())

    values = [v[0] for v in sorted_counts]
    counts = [v[1] for v in sorted_counts]

    plt.figure(figsize=(10,8))
    plt.bar(x=values, height=counts)
    plt.show()

# %%
values = np.random.randint(1, 50, 10000)  # 10000 random integers between 1 to 49

plot_bar(values)

# %% [markdown]
# ### Simulating random experiments

# %% [markdown]
# #### Simulate coin toss

# %%
np.random.rand(1)[0]
# Out:
# np.float64(0.2250074169086831)

# %%
### Unbiased coin (equal probabilities of getting head and tail)

### Biased coin (head with probability p and tail with probaility (1-p))

def simulate_cointoss(p = 0.5):
    """ Simulate a coin toss with head probability p """

    if p > 1.0 or p < 0:
        raise ValueError("The probability p should be between 0 to 1")
    
    v = np.random.rand(1)[0]

    if v <= p:
        return 'H'
    else:
        return 'T'

# %%
def multiple_cointoss(n, p=0.5):
    """Simulate n coin tosses with head probability p"""

    results = [simulate_cointoss(p) for i in range(n)]

    return results

# %%
results = multiple_cointoss(1000, p=0.5)

# %%
plot_bar(results)

# %%
results = multiple_cointoss(1000, p=0.2)

plot_bar(results)

# %%
results = multiple_cointoss(1000, p=0.7)

plot_bar(results)

# %% [markdown]
# #### Simulate dice roll

# %%
np.random.randint(6)   # random number between 0 to 5
# Out:
# 3

# %%
np.random.randint(6) + 1     # random number between 1 to 6
# Out:
# 6

# %%
np.random.randint(low=1, high=7)  # random number between 1 to 6
# Out:
# 4

# %%
results = np.random.randint(1, 7, 10000)

plot_bar(results)

# %% [markdown]
# ### Cumulative frequency and Cumulative distribution

# %%
values = np.random.normal(4, 2, 10000)

# %%
plot_hist(values)

# %%
n,bins,patches = plt.hist(values, bins=20, edgecolor='k')

# %%
n
# Out:
# array([1.000e+00, 1.200e+01, 2.800e+01, 7.700e+01, 1.750e+02, 3.760e+02,
#        6.660e+02, 1.020e+03, 1.361e+03, 1.540e+03, 1.499e+03, 1.202e+03,
#        9.100e+02, 6.040e+02, 3.320e+02, 1.380e+02, 3.700e+01, 1.600e+01,
#        4.000e+00, 2.000e+00])

# %%
np.cumsum(n)
# Out:
# array([1.000e+00, 1.300e+01, 4.100e+01, 1.180e+02, 2.930e+02, 6.690e+02,
#        1.335e+03, 2.355e+03, 3.716e+03, 5.256e+03, 6.755e+03, 7.957e+03,
#        8.867e+03, 9.471e+03, 9.803e+03, 9.941e+03, 9.978e+03, 9.994e+03,
#        9.998e+03, 1.000e+04])

# %%
bins
# Out:
# array([-3.70486813, -2.92589267, -2.1469172 , -1.36794174, -0.58896627,
#         0.1900092 ,  0.96898466,  1.74796013,  2.5269356 ,  3.30591106,
#         4.08488653,  4.86386199,  5.64283746,  6.42181293,  7.20078839,
#         7.97976386,  8.75873932,  9.53771479, 10.31669026, 11.09566572,
#        11.87464119])

# %%
plt.figure(figsize=(10,8))

plt.hist(values, bins=20, cumulative=True, edgecolor='k', color='c')
plt.hist(values, bins=20, cumulative=False, edgecolor='k', color='m')

plt.show()
